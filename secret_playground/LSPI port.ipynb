# %%
# %matplotlib inline
import numpy as np
import scipy.linalg
import matplotlib.pylab as plt
import seaborn as sns
import time
sns.set_style('ticks')

# %%
class InstabilityException(Exception):
    def __init__(self, msg=None):
        super().__init__(msg)
        
class RankDegeneracyException(Exception):
    def __init__(self, msg=None):
        super().__init__(msg)

def _assert_matrix(M):
    assert len(M.shape) == 2
    
def _assert_square_matrix(M):
    _assert_matrix(M)
    assert M.shape[0] == M.shape[1]

def _assert_symmetric_matrix(M):
    _assert_square_matrix(M)
    assert np.allclose(M, M.T)
    
def svec(M):
    assert len(M.shape) == 2
    assert M.shape[0] == M.shape[1]
    diag = np.diag(M)
    off_diag = np.sqrt(2)*M[np.triu_indices(M.shape[0], k=1)]
    return np.hstack((diag, off_diag))

def smat(v):
    n = int((np.sqrt(1+8*v.shape[0])-1)/2)
    assert n*(n+1) == 2*v.shape[0]
    V = np.zeros((n, n))
    off_diag = v[n:]/np.sqrt(2.0)
    V[np.triu_indices(V.shape[0], k=1)] = off_diag
    V += V.T
    V[np.diag_indices(V.shape[0])] = v[:n]
    return V

def sym(M):
    return (M+M.T)/2

def spectral_radius(L):
    evs = np.linalg.eigvals(L)
    rho = max(np.abs(evs))
    return rho

def is_stable(L):
    return spectral_radius(L) < 1

def lambda_min(H):
    evs = np.linalg.eigvalsh(H)
    return min(evs)

def lambda_max(H):
    evs = np.linalg.eigvalsh(H)
    return max(evs)

class LQR_instance(object):
    
    def __init__(self, A, B, Q, R, gamma, sigma_w):
        _assert_square_matrix(A)
        self.A_ = np.array(A)
        self.state_dim_ = A.shape[0]
        _assert_matrix(B)
        assert B.shape[0] == self.state_dim_
        self.B_ = np.array(B)
        self.input_dim_ = B.shape[1]
        _assert_symmetric_matrix(Q) #assume PD
        assert Q.shape[0] == self.state_dim_
        self.Q_ = np.array(Q)
        _assert_symmetric_matrix(R) #assume PD
        assert R.shape[0] == self.input_dim_
        self.R_ = np.array(R)
        assert gamma > 0 and gamma < 1
        self.gamma_ = gamma
        self.eta_ = gamma/(1-gamma)
        assert sigma_w >= 0
        self.sigma_w_ = sigma_w
        
    def rollout_off_policy(self, T, sigma_u, x0=None, rng=None):
        """Explore with random Gaussian noise of variance sigma_u^2,
        starting with x0 given 
        
        """
        rng = np.random if rng is None else rng
        trajectory = []
        x0 = np.zeros((self.state_dim_,)) if x0 is None else x0
        xk = np.array(x0)
        for k in range(T):
            # draw exploration input
            uk = sigma_u*rng.normal(size=(self.input_dim_,))
            
            # receive reward
            rk = xk.dot(self.Q_).dot(xk) + uk.dot(self.R_).dot(uk)
            
            # take a step
            wk = self.sigma_w_*rng.normal(size=(self.state_dim_,))
            xkp1 = self.A_.dot(xk) + self.B_.dot(uk) + wk
            
            # emit (xk, uk, rk, xkp1)
            trajectory.append((xk, uk, rk, xkp1))
            
            xk = np.copy(xkp1)
        return trajectory

    def rollout(self, K, T, rng=None):
        rng = np.random if rng is None else rng
        trajectory = []
        L = self.A_ + self.B_.dot(K)
        x0 = np.zeros((self.state_dim_,))
        xk = np.array(x0)
        M = self.Q_ + K.T.dot(self.R_.dot(K))
        for k in range(T):
            # receive reward
            rk = xk.dot(M.dot(xk))

            # take a step
            wk = self.sigma_w_*rng.normal(size=(L.shape[0],))
            xkp1 = L.dot(xk) + wk

            # emit (xk, rk, xkp1)
            trajectory.append((xk, rk, xkp1))

            xk = np.copy(xkp1)
        return trajectory
        
    def phi(self, x):
        assert x.shape == (self.state_dim_,)
        return svec(np.outer(x, x) + (self.sigma_w_**2)*self.eta_*np.eye(self.state_dim_))
        
    def solve_stationary(self, K):
        """Compute the covariance of the stationary distribution of
        x_{k+1} = (A+BK) x_{k} + w_k, w_k ~ N(0, sigma^2 I)
        
        """
        L = self.A_ + self.B_.dot(K)
        P_infty = scipy.linalg.solve_discrete_lyapunov(L, self.sigma_w_*self.sigma_w_*np.eye(self.state_dim_))
        
        assert np.allclose(
            L.dot(P_infty).dot(L.T) - P_infty + self.sigma_w_*self.sigma_w_*np.eye(self.state_dim_),
            np.zeros_like(P_infty)
        )
        
        _assert_symmetric_matrix(P_infty)
        assert lambda_min(P_infty) >= -1e-10

        return P_infty
    
    def lstd_Q(self, trajectory, K):
        """Given a trajectory, use LSTD to compute 
        Q^pi(x, u)
        
        """
        
        eta = self.eta_
        IK = np.vstack((np.eye(self.state_dim_), K))
        feature_offset = (self.sigma_w_**2)*eta*IK.dot(IK.T)
        
        def phi_Q(x, u):
            xu = np.hstack((x, u))
            return svec(np.outer(xu, xu) + feature_offset)
        
        Phi = np.array([phi_Q(xk, uk) for xk, uk, _, _ in trajectory])
        Phi_plus = np.array([phi_Q(xkp1, K.dot(xkp1)) for _, _, _, xkp1 in trajectory])
        rvec = np.array([rk for _, _, rk, _ in trajectory])
        PhiTPhi = Phi.T.dot(Phi)
        Amat = PhiTPhi - self.gamma_*Phi.T.dot(Phi_plus)
    
        # Check if Phi is full column rank
        svals_Phi = np.linalg.eigvalsh(PhiTPhi)
        if min(svals_Phi) <= 1e-8:
            raise RankDegeneracyException(
                "Phi matrix is degenerate: s_min(Phi)={}".format(min(svals_Phi)))
        
        # check if Amat is full rank
        svals = scipy.linalg.svdvals(Amat)
        if min(svals) <= 1e-8:
            raise RankDegeneracyException(
                "Amat is degenerate: s_min(Amat)={}".format(min(svals)))
        
        Bmat = Phi.T.dot(rvec)
        phat = np.linalg.lstsq(Amat, Bmat)[0]
        return Phi, Phi_plus, rvec, phat
    
    def lstd(self, trajectory):
        Phi = np.array([self.phi(xk) for xk, _, _ in trajectory])
        Phi_plus = np.array([self.phi(xkp1) for _, _, xkp1 in trajectory])
        rvec = np.array([rk for _, rk, _ in trajectory])
        Amat = Phi.T.dot(Phi) - self.gamma_*Phi.T.dot(Phi_plus)
        Bmat = Phi.T.dot(rvec)
        phat = np.linalg.lstsq(Amat, Bmat)[0]
        return Phi, Phi_plus, rvec, phat
    
    def estimate_nominal(self, trajectory):
        """estimate Ahat, Bhat from the given trajectory
        
        """
        
        # number of data points by (n+p)
        BigX = np.array([np.hstack((xk, uk)) for xk, uk, _, _ in trajectory])

        # number of data points by n
        BigY = np.array([xkp1 for _, _, _, xkp1 in trajectory])
        
        soln, _, _, _ = np.linalg.lstsq(BigX, BigY) # soln = [A, B]^T
        
        Ahat_T = soln[:self.state_dim_,:]
        Bhat_T = soln[self.state_dim_:,:]
        
        Ahat, Bhat = Ahat_T.T, Bhat_T.T

        return Ahat, Bhat
    
    def solve_nominal(self, Ahat, Bhat, discount):
        return self._solve(
            np.array(Ahat),
            np.array(Bhat),
            np.array(self.Q_),
            np.array(self.R_),
            self.gamma_ if discount else 1.0)
    
    def _solve(self, A, B, Q, R, gamma):
        assert gamma >= 0 and gamma <= 1
        
        P_star = scipy.linalg.solve_discrete_are(np.sqrt(gamma)*A, B, Q, (1.0/gamma)*R)

        assert np.allclose(
            P_star,
            gamma*A.T.dot(P_star).dot(A) -
            gamma*gamma*A.T.dot(P_star).dot(B)
                .dot(scipy.linalg.solve(R + gamma*B.T.dot(P_star).dot(B), np.eye(R.shape[0])))
                .dot(B.T.dot(P_star).dot(A)) + Q
        )

        _assert_symmetric_matrix(P_star)
        assert lambda_min(P_star) >= -1e-10
        
        neg_K_star = gamma*scipy.linalg.solve(gamma*B.T.dot(P_star).dot(B) + R, np.eye(R.shape[0])).dot(B.T.dot(P_star).dot(A))
        K_star = -neg_K_star
        
        # TODO: should check controllability and observability assumptions
        L_star = A + B.dot(K_star)
        assert is_stable(np.sqrt(gamma)*L_star)
        
        return P_star, K_star
        
    def solve(self, discount):
        """Solve the problem
        
        Returns the parameterization P of an optimal value function,
        and returns an optimal policy pi(x) = K x
        
        """
        return self._solve(
            np.array(self.A_),
            np.array(self.B_),
            np.array(self.Q_),
            np.array(self.R_),
            self.gamma_ if discount else 1.0)

    def score(self, P, discount):
        """P is a parameterization of a value function
        
        """
        _assert_symmetric_matrix(P)
        if discount:
            return self.sigma_w_*self.sigma_w_/(1-self.gamma_)*np.trace(P)
        else:
            return self.sigma_w_*self.sigma_w_*np.trace(P)
        
    def solve_value_function(self, K, discount):
        """Compute the value function associated to the policy pi(x) = Kx
        
        It is given by the
        
        """
        _assert_matrix(K)
        assert K.shape == (self.input_dim_, self.state_dim_)
        
        effective_gamma = self.gamma_ if discount else 1.0
        
        L = self.A_ + self.B_.dot(K)
        # check that sqrt(gamma)*L is stable
        if not is_stable(np.sqrt(effective_gamma)*L):
            raise InstabilityException("closed loop sqrt(eff_gamma)*(A+BK) is not stable")

        # solve (sqrt(gamma) L)^T P (sqrt(gamma) L) - P + (Q+K^T R K) = 0
        P_pi = scipy.linalg.solve_discrete_lyapunov(np.sqrt(effective_gamma)*L.T, self.Q_+K.T.dot(self.R_.dot(K)))
        
        # check that this version of scipy is consistent w/ dlyap
        assert np.allclose(
            (np.sqrt(effective_gamma)*L.T).dot(P_pi).dot(np.sqrt(effective_gamma)*L) - P_pi 
            + self.Q_ + K.T.dot(self.R_).dot(K),
            np.zeros_like(P_pi)
        )

        # check that P_pi is symmetric positive definite
        _assert_symmetric_matrix(P_pi)
        assert lambda_min(P_pi) >= -1e-10

        return P_pi
    
    def greedy_update(self, P):
        """Given a parameterization of a Q function
        Q^pi(x,u) = - (x,u)^T P (x,u) - q,
        
        compute a new feedback policy by greedy maximization
        
        """
        
        _assert_symmetric_matrix(P)
        assert P.shape[0] == (self.state_dim_ + self.input_dim_)
        
        P12 = P[:self.state_dim_, self.state_dim_:]
        P22 = P[self.state_dim_:, self.state_dim_:]
        
        return -scipy.linalg.solve(P22, P12.T, sym_pos=True)
    
    def solve_q_function(self, K):
        """Compute the Q function associated to the policy pi(x) = Kx
        
        """

        _assert_matrix(K)
        assert K.shape == (self.input_dim_, self.state_dim_)
        
        L = self.A_ + self.B_.dot(K)
        # check that L is stable
        if not is_stable(np.sqrt(self.gamma_)*L):
            raise InstabilityException("sqrt(gamma)*(A+BK) is not stable")
            
        AB = np.hstack((self.A_, self.B_))
        IK = np.vstack((np.eye(self.state_dim_), K))
        
        QR = np.vstack((
            np.hstack((self.Q_, np.zeros((self.state_dim_, self.input_dim_)))),
            np.hstack((np.zeros((self.input_dim_, self.state_dim_)), self.R_))))

        P = scipy.linalg.solve_discrete_lyapunov(np.sqrt(self.gamma_)*(IK.dot(AB)).T, QR)
        _assert_symmetric_matrix(P)
        assert lambda_min(P) >= -1e-10
        return P
    
def lqr_tests():
    A = np.array([[1, 0], [1, 1]])
    B = np.array([[0, 0], [1, 0]])
    Q = 1e-3 * np.eye(2)
    R = np.eye(2)
    gamma = 0.9
    
    K = np.array([
        [0, -0.5],
        [0.5, 1]])
    
    assert is_stable(np.sqrt(gamma)*(A+B.dot(K)))
    
    n, p = 2, 2
    n_params_q = int((n+p)*(n+p+1)/2) 
    
    prob = LQR_instance(A, B, Q, R, gamma, sigma_w=0)
    P0 = prob.solve_q_function(K)
    x0 = np.random.normal(size=(n,))
    traj = prob.rollout_off_policy(T=n_params_q, sigma_u=1, x0=x0)
    _, _, _, phat = prob.lstd_Q(traj, K)
    Phat0 = smat(phat)
    
    assert np.allclose(P0, Phat0)
    
    _, Kstar = prob.solve(discount=True)
    Jstar = np.trace(prob.solve_value_function(Kstar, discount=True))
    
    # check policy iteration
    Jcur = np.trace(prob.solve_value_function(K, discount=True))
    Kcur = K
    Pcur = P0
    while 1:
        # update
        Knext = prob.greedy_update(Pcur)
        
        # score next
        Pnext = prob.solve_q_function(Knext)
        Jnext = np.trace(prob.solve_value_function(Knext, discount=True))
        
        assert Jnext <= Jcur
        
        if (Jcur - Jnext)/Jcur <= 1e-5:
            break
            
        Jcur, Kcur, Pcur = Jnext, Knext, Pnext
        
    # check final score
    assert (Jcur - Jstar)/Jstar <= 1e-5

# %%
lqr_tests()

# %%
A = np.array([
    [1.01, 0.01, 0],
    [0.01, 1.01, 0.01],
    [0, 0.01, 1.01]
])
B = np.eye(3)
Q = 1e-3 * np.eye(3)
R = np.eye(3)

gamma = 0.98
prob = LQR_instance(A, B, Q, R, gamma, 1.0)
P_star, K_star = prob.solve(discount=True)
P_avg_star, K_avg_star = prob.solve(discount=False)
J_star, J_star_avg = prob.score(P_star, discount=True), prob.score(P_avg_star, discount=False)
print("J_star (gamma):", J_star, "J_star (avg):", J_star_avg)
print("rho(A+BK)", spectral_radius(A+B.dot(K_star)))

# check how good optimal discount soln is for avg cost
P_hat = prob.solve_value_function(K_star, discount=False)
J_hat = prob.score(P_hat, discount=False)
assert J_hat >= J_star_avg
print("(J_hat - J_star_avg)/J_star_avg", (J_hat - J_star_avg)/J_star_avg)

# arbitrary starting point
K0 = -np.array([
    [0.41, 0.01, 0],
    [0.01, 0.41, 0.01],
    [0, 0.01, 0.41]
])
print("rho(A+BK0)", spectral_radius(A+B.dot(K0)))

# naive score
P_K0 = prob.solve_value_function(K0, discount=True)
J_K0 = prob.score(P_K0, discount=True)
print("J_{K0}",J_K0, "(J_{K0} - J_star)/J_star", (J_K0 - J_star)/J_star)
print(A+B.dot(K0))

P_K0 = prob.solve_value_function(K0, discount=False)
J_K0 = prob.score(P_K0, discount=False)
print("J_{K0}",J_K0, "(J_{K0} - J_star_avg)/J_star_avg", (J_K0 - J_star_avg)/J_star_avg)
# Out:
# J_star (gamma): 5.15859259193 J_star (avg): 0.137287165978
# rho(A+BK) 0.979018198485
# (J_hat - J_star_avg)/J_star_avg 0.0694714351996
# rho(A+BK0) 0.6
# J_{K0} 39.2228059333 (J_{K0} - J_star)/J_star 6.60339283133
# [[ 0.6  0.   0. ]
#  [ 0.   0.6  0. ]
#  [ 0.   0.   0.6]]
# J_{K0} 0.79328125 (J_{K0} - J_star_avg)/J_star_avg 4.77826226034

# %%
def lspi(prob, traj, K_init):
    def check_weighted_stable(K):
        if spectral_radius(np.sqrt(prob.gamma_)*(prob.A_ + prob.B_.dot(K))) >= 1:
            raise InstabilityException()
    
    K_cur = np.array(K_init)
    check_weighted_stable(K_cur)
    cur_cost = prob.score(prob.solve_value_function(K_cur, discount=True), discount=True)
    while 1:
        #print("rho(gamma*CLP)", spectral_radius(np.sqrt(gamma)*(A+B.dot(K_cur))))
        _, _, _, qhat = prob.lstd_Q(traj, K_cur)
        K_propose = prob.greedy_update(smat(qhat))
        check_weighted_stable(K_propose)
        
        # compute new
        new_cost = prob.score(prob.solve_value_function(K_propose, discount=True), discount=True)
        #print("cur_cost", cur_cost, "new_cost", new_cost)

        if np.abs(cur_cost-new_cost)/np.abs(cur_cost) <= 1e-5:
            #print("exiting")
            break

        K_cur = K_propose
        cur_cost = new_cost
        
    return K_cur, cur_cost

# %%
def collect_samples(prob, NT, T):
    assert T <= NT
    samples = []
    while len(samples) < NT:
        remaining = NT - len(samples)
        samples.extend(prob.rollout_off_policy(min(T, remaining), 1.0))
    return samples

# %%
T = 20
#N_values = [20, 40, 60, 80, 100]
#NT_values = [N*T for N in N_values]
NT_values = [250, 500, 750, 1000, 2000, 3000, 4000, 5000]
n_trials = 100
all_trajectories = []
for _ in range(n_trials):
    all_trajectories.append(collect_samples(prob, max(NT_values), T))

# %%
# sanity
Q_pizero = prob.solve_q_function(K0)
error_lspi = np.zeros((n_trials, len(NT_values)))
for idx, traj in enumerate(all_trajectories):
    for jdx, NT_value in enumerate(NT_values):
        
        iter_start = time.time()
        
        sample = traj[:NT_value]
        _, _, _, qhat = prob.lstd_Q(sample, K0)
        Qhat = smat(qhat)
        error_lspi[idx, jdx] = np.linalg.norm(Q_pizero - Qhat, ord='fro')/np.linalg.norm(Q_pizero, ord='fro')
        print("done with pair (idx, jdx)", (idx, jdx), "in {} seconds".format(time.time() - iter_start))
# Out:
# done with pair (idx, jdx) (0, 0) in 0.0306549072265625 seconds
# done with pair (idx, jdx) (0, 1) in 0.06129789352416992 seconds
# done with pair (idx, jdx) (0, 2) in 0.06448221206665039 seconds
# done with pair (idx, jdx) (0, 3) in 0.06575703620910645 seconds
# done with pair (idx, jdx) (0, 4) in 0.15710997581481934 seconds
# done with pair (idx, jdx) (0, 5) in 0.19704484939575195 seconds
# done with pair (idx, jdx) (0, 6) in 0.2632269859313965 seconds
# done with pair (idx, jdx) (0, 7) in 0.32811594009399414 seconds
# done with pair (idx, jdx) (1, 0) in 0.01672816276550293 seconds
# done with pair (idx, jdx) (1, 1) in 0.03158402442932129 seconds
# done with pair (idx, jdx) (1, 2) in 0.04832601547241211 seconds
# done with pair (idx, jdx) (1, 3) in 0.06038808822631836 seconds
# done with pair (idx, jdx) (1, 4) in 0.1443328857421875 seconds
# done with pair (idx, jdx) (1, 5) in 0.18512701988220215 seconds
# done with pair (idx, jdx) (1, 6) in 0.2656741142272949 seconds
# done with pair (idx, jdx) (1, 7) in 0.35443830490112305 seconds
# done with pair (idx, jdx) (2, 0) in 0.019921064376831055 seconds
# done with pair (idx, jdx) (2, 1) in 0.03791403770446777 seconds
# done with pair (idx, jdx) (2, 2) in 0.058084964752197266 seconds
# done with pair (idx, jdx) (2, 3) in 0.06878900527954102 seconds
# done with pair (idx, jdx) (2, 4) in 0.15530824661254883 seconds
# done with pair (idx, jdx) (2, 5) in 0.18418097496032715 seconds
# done with pair (idx, jdx) (2, 6) in 0.2855260372161865 seconds
# done with pair (idx, jdx) (2, 7) in 0.32881999015808105 seconds
# done with pair (idx, jdx) (3, 0) in 0.01847672462463379 seconds
# done with pair (idx, jdx) (3, 1) in 0.03651595115661621 seconds
# done with pair (idx, jdx) (3, 2) in 0.0511322021484375 seconds
# done with pair (idx, jdx) (3, 3) in 0.0673060417175293 seconds
# done with pair (idx, jdx) (3, 4) in 0.16158509254455566 seconds
# done with pair (idx, jdx) (3, 5) in 0.19250702857971191 seconds
# done with pair (idx, jdx) (3, 6) in 0.27606725692749023 seconds
# done with pair (idx, jdx) (3, 7) in 0.32898998260498047 seconds
# done with pair (idx, jdx) (4, 0) in 0.018277883529663086 seconds
# done with pair (idx, jdx) (4, 1) in 0.030811071395874023 seconds
# done with pair (idx, jdx) (4, 2) in 0.050048828125 seconds
# done with pair (idx, jdx) (4, 3) in 0.06477212905883789 seconds
# done with pair (idx, jdx) (4, 4) in 0.15766668319702148 seconds
# done with pair (idx, jdx) (4, 5) in 0.21350908279418945 seconds
# done with pair (idx, jdx) (4, 6) in 0.3034377098083496 seconds
# done with pair (idx, jdx) (4, 7) in 0.3333780765533447 seconds
# done with pair (idx, jdx) (5, 0) in 0.018478870391845703 seconds
# done with pair (idx, jdx) (5, 1) in 0.034716129302978516 seconds
# done with pair (idx, jdx) (5, 2) in 0.05052018165588379 seconds
# done with pair (idx, jdx) (5, 3) in 0.06939911842346191 seconds
# done with pair (idx, jdx) (5, 4) in 0.19109177589416504 seconds
# done with pair (idx, jdx) (5, 5) in 0.20142531394958496 seconds
# done with pair (idx, jdx) (5, 6) in 0.2871389389038086 seconds
# done with pair (idx, jdx) (5, 7) in 0.3938009738922119 seconds
# done with pair (idx, jdx) (6, 0) in 0.02295994758605957 seconds
# done with pair (idx, jdx) (6, 1) in 0.04921388626098633 seconds
# done with pair (idx, jdx) (6, 2) in 0.05961799621582031 seconds
# done with pair (idx, jdx) (6, 3) in 0.07650089263916016 seconds
# done with pair (idx, jdx) (6, 4) in 0.16462397575378418 seconds
# done with pair (idx, jdx) (6, 5) in 0.2434978485107422 seconds
# done with pair (idx, jdx) (6, 6) in 0.2818269729614258 seconds
# done with pair (idx, jdx) (6, 7) in 0.3504359722137451 seconds
# done with pair (idx, jdx) (7, 0) in 0.022315025329589844 seconds
# done with pair (idx, jdx) (7, 1) in 0.037101030349731445 seconds
# done with pair (idx, jdx) (7, 2) in 0.10009431838989258 seconds
# done with pair (idx, jdx) (7, 3) in 0.11105823516845703 seconds
# done with pair (idx, jdx) (7, 4) in 0.22736191749572754 seconds
# done with pair (idx, jdx) (7, 5) in 0.25525975227355957 seconds
# done with pair (idx, jdx) (7, 6) in 0.34160614013671875 seconds
# done with pair (idx, jdx) (7, 7) in 0.3802940845489502 seconds
# done with pair (idx, jdx) (8, 0) in 0.024752140045166016 seconds
# done with pair (idx, jdx) (8, 1) in 0.03441309928894043 seconds
# done with pair (idx, jdx) (8, 2) in 0.062239885330200195 seconds
# done with pair (idx, jdx) (8, 3) in 0.06464290618896484 seconds
# done with pair (idx, jdx) (8, 4) in 0.18165087699890137 seconds
# done with pair (idx, jdx) (8, 5) in 0.29759716987609863 seconds
# done with pair (idx, jdx) (8, 6) in 0.2936530113220215 seconds
# done with pair (idx, jdx) (8, 7) in 0.36821603775024414 seconds
# done with pair (idx, jdx) (9, 0) in 0.02236008644104004 seconds
# done with pair (idx, jdx) (9, 1) in 0.03855586051940918 seconds
# done with pair (idx, jdx) (9, 2) in 0.04903984069824219 seconds
# done with pair (idx, jdx) (9, 3) in 0.07121109962463379 seconds
# done with pair (idx, jdx) (9, 4) in 0.16413593292236328 seconds
# done with pair (idx, jdx) (9, 5) in 0.19655704498291016 seconds
# done with pair (idx, jdx) (9, 6) in 0.29369306564331055 seconds
# done with pair (idx, jdx) (9, 7) in 0.35846781730651855 seconds
# done with pair (idx, jdx) (10, 0) in 0.01703786849975586 seconds
# done with pair (idx, jdx) (10, 1) in 0.037513017654418945 seconds
# done with pair (idx, jdx) (10, 2) in 0.05312299728393555 seconds
# done with pair (idx, jdx) (10, 3) in 0.0672609806060791 seconds
# done with pair (idx, jdx) (10, 4) in 0.16642308235168457 seconds
# done with pair (idx, jdx) (10, 5) in 0.19751286506652832 seconds
# done with pair (idx, jdx) (10, 6) in 0.2879488468170166 seconds
# done with pair (idx, jdx) (10, 7) in 0.3430609703063965 seconds
# done with pair (idx, jdx) (11, 0) in 0.01896381378173828 seconds
# done with pair (idx, jdx) (11, 1) in 0.042829036712646484 seconds
# done with pair (idx, jdx) (11, 2) in 0.04985308647155762 seconds
# done with pair (idx, jdx) (11, 3) in 0.09428787231445312 seconds
# done with pair (idx, jdx) (11, 4) in 0.17285871505737305 seconds
# done with pair (idx, jdx) (11, 5) in 0.23127007484436035 seconds
# done with pair (idx, jdx) (11, 6) in 0.3418259620666504 seconds
# done with pair (idx, jdx) (11, 7) in 0.4198768138885498 seconds
# done with pair (idx, jdx) (12, 0) in 0.0553131103515625 seconds
# done with pair (idx, jdx) (12, 1) in 0.037915945053100586 seconds
# done with pair (idx, jdx) (12, 2) in 0.05376482009887695 seconds
# done with pair (idx, jdx) (12, 3) in 0.07364082336425781 seconds
# done with pair (idx, jdx) (12, 4) in 0.17630219459533691 seconds
# done with pair (idx, jdx) (12, 5) in 0.29226016998291016 seconds
# done with pair (idx, jdx) (12, 6) in 0.28238797187805176 seconds
# done with pair (idx, jdx) (12, 7) in 0.4326779842376709 seconds
# done with pair (idx, jdx) (13, 0) in 0.02654290199279785 seconds
# done with pair (idx, jdx) (13, 1) in 0.0427241325378418 seconds
# done with pair (idx, jdx) (13, 2) in 0.05711793899536133 seconds
# done with pair (idx, jdx) (13, 3) in 0.06919574737548828 seconds
# done with pair (idx, jdx) (13, 4) in 0.22311902046203613 seconds
# done with pair (idx, jdx) (13, 5) in 0.24684810638427734 seconds
# done with pair (idx, jdx) (13, 6) in 0.3545718193054199 seconds
# done with pair (idx, jdx) (13, 7) in 0.3869037628173828 seconds
# done with pair (idx, jdx) (14, 0) in 0.026733875274658203 seconds
# done with pair (idx, jdx) (14, 1) in 0.06377005577087402 seconds
# done with pair (idx, jdx) (14, 2) in 0.08600020408630371 seconds
# done with pair (idx, jdx) (14, 3) in 0.14010906219482422 seconds
# done with pair (idx, jdx) (14, 4) in 0.19388508796691895 seconds
# done with pair (idx, jdx) (14, 5) in 0.23135781288146973 seconds
# done with pair (idx, jdx) (14, 6) in 0.3494846820831299 seconds
# done with pair (idx, jdx) (14, 7) in 0.35396265983581543 seconds
# done with pair (idx, jdx) (15, 0) in 0.0180971622467041 seconds
# done with pair (idx, jdx) (15, 1) in 0.035310983657836914 seconds
# done with pair (idx, jdx) (15, 2) in 0.048982858657836914 seconds
# done with pair (idx, jdx) (15, 3) in 0.06345081329345703 seconds
# done with pair (idx, jdx) (15, 4) in 0.1379079818725586 seconds
# done with pair (idx, jdx) (15, 5) in 0.20254015922546387 seconds
# done with pair (idx, jdx) (15, 6) in 0.29858827590942383 seconds
# done with pair (idx, jdx) (15, 7) in 0.3474760055541992 seconds
# done with pair (idx, jdx) (16, 0) in 0.021700143814086914 seconds
# done with pair (idx, jdx) (16, 1) in 0.03352665901184082 seconds
# done with pair (idx, jdx) (16, 2) in 0.052459001541137695 seconds
# done with pair (idx, jdx) (16, 3) in 0.06286287307739258 seconds
# done with pair (idx, jdx) (16, 4) in 0.15043997764587402 seconds
# done with pair (idx, jdx) (16, 5) in 0.19939184188842773 seconds
# done with pair (idx, jdx) (16, 6) in 0.26087379455566406 seconds
# done with pair (idx, jdx) (16, 7) in 0.31549692153930664 seconds
# done with pair (idx, jdx) (17, 0) in 0.016561269760131836 seconds
# done with pair (idx, jdx) (17, 1) in 0.0336308479309082 seconds
# done with pair (idx, jdx) (17, 2) in 0.05041384696960449 seconds
# done with pair (idx, jdx) (17, 3) in 0.06103396415710449 seconds
# done with pair (idx, jdx) (17, 4) in 0.15442991256713867 seconds
# done with pair (idx, jdx) (17, 5) in 0.19541287422180176 seconds
# done with pair (idx, jdx) (17, 6) in 0.28143906593322754 seconds
# done with pair (idx, jdx) (17, 7) in 0.33109378814697266 seconds
# done with pair (idx, jdx) (18, 0) in 0.021274805068969727 seconds
# done with pair (idx, jdx) (18, 1) in 0.03287005424499512 seconds
# done with pair (idx, jdx) (18, 2) in 0.06126284599304199 seconds
# done with pair (idx, jdx) (18, 3) in 0.06865811347961426 seconds
# done with pair (idx, jdx) (18, 4) in 0.15279483795166016 seconds
# done with pair (idx, jdx) (18, 5) in 0.2023169994354248 seconds
# done with pair (idx, jdx) (18, 6) in 0.26099705696105957 seconds
# done with pair (idx, jdx) (18, 7) in 0.3445920944213867 seconds
# done with pair (idx, jdx) (19, 0) in 0.01699686050415039 seconds
# done with pair (idx, jdx) (19, 1) in 0.03637385368347168 seconds
# done with pair (idx, jdx) (19, 2) in 0.0549929141998291 seconds
# done with pair (idx, jdx) (19, 3) in 0.0659949779510498 seconds
# done with pair (idx, jdx) (19, 4) in 0.15150690078735352 seconds
# done with pair (idx, jdx) (19, 5) in 0.2026808261871338 seconds
# done with pair (idx, jdx) (19, 6) in 0.26921534538269043 seconds
# done with pair (idx, jdx) (19, 7) in 0.3502311706542969 seconds
# done with pair (idx, jdx) (20, 0) in 0.03788495063781738 seconds
# done with pair (idx, jdx) (20, 1) in 0.07088422775268555 seconds
# done with pair (idx, jdx) (20, 2) in 0.09012198448181152 seconds
# done with pair (idx, jdx) (20, 3) in 0.12033367156982422 seconds
# done with pair (idx, jdx) (20, 4) in 0.14944982528686523 seconds
# done with pair (idx, jdx) (20, 5) in 0.3447227478027344 seconds
# done with pair (idx, jdx) (20, 6) in 0.2976689338684082 seconds
# done with pair (idx, jdx) (20, 7) in 0.36344003677368164 seconds
# done with pair (idx, jdx) (21, 0) in 0.024037837982177734 seconds
# done with pair (idx, jdx) (21, 1) in 0.038213253021240234 seconds
# done with pair (idx, jdx) (21, 2) in 0.05795884132385254 seconds
# done with pair (idx, jdx) (21, 3) in 0.07102799415588379 seconds
# done with pair (idx, jdx) (21, 4) in 0.16164588928222656 seconds
# done with pair (idx, jdx) (21, 5) in 0.20496201515197754 seconds
# done with pair (idx, jdx) (21, 6) in 0.292618989944458 seconds
# done with pair (idx, jdx) (21, 7) in 0.35271310806274414 seconds
# done with pair (idx, jdx) (22, 0) in 0.027382850646972656 seconds
# done with pair (idx, jdx) (22, 1) in 0.04847908020019531 seconds
# done with pair (idx, jdx) (22, 2) in 0.049356698989868164 seconds
# done with pair (idx, jdx) (22, 3) in 0.07427215576171875 seconds
# done with pair (idx, jdx) (22, 4) in 0.15805888175964355 seconds
# done with pair (idx, jdx) (22, 5) in 0.19449329376220703 seconds
# done with pair (idx, jdx) (22, 6) in 0.3571028709411621 seconds
# done with pair (idx, jdx) (22, 7) in 0.40340399742126465 seconds
# done with pair (idx, jdx) (23, 0) in 0.03447985649108887 seconds
# done with pair (idx, jdx) (23, 1) in 0.059545040130615234 seconds
# done with pair (idx, jdx) (23, 2) in 0.08466601371765137 seconds
# done with pair (idx, jdx) (23, 3) in 0.110321044921875 seconds
# done with pair (idx, jdx) (23, 4) in 0.2578768730163574 seconds
# done with pair (idx, jdx) (23, 5) in 0.3085470199584961 seconds
# done with pair (idx, jdx) (23, 6) in 0.3484470844268799 seconds
# done with pair (idx, jdx) (23, 7) in 0.35309696197509766 seconds
# done with pair (idx, jdx) (24, 0) in 0.018130779266357422 seconds
# done with pair (idx, jdx) (24, 1) in 0.033838748931884766 seconds
# done with pair (idx, jdx) (24, 2) in 0.05072283744812012 seconds
# done with pair (idx, jdx) (24, 3) in 0.06550192832946777 seconds
# done with pair (idx, jdx) (24, 4) in 0.1928551197052002 seconds
# done with pair (idx, jdx) (24, 5) in 0.20229768753051758 seconds
# done with pair (idx, jdx) (24, 6) in 0.30151987075805664 seconds
# done with pair (idx, jdx) (24, 7) in 0.3620119094848633 seconds
# done with pair (idx, jdx) (25, 0) in 0.024943828582763672 seconds
# done with pair (idx, jdx) (25, 1) in 0.04351687431335449 seconds
# done with pair (idx, jdx) (25, 2) in 0.051061153411865234 seconds
# done with pair (idx, jdx) (25, 3) in 0.0720367431640625 seconds
# done with pair (idx, jdx) (25, 4) in 0.1604321002960205 seconds
# done with pair (idx, jdx) (25, 5) in 0.19903111457824707 seconds
# done with pair (idx, jdx) (25, 6) in 0.2974100112915039 seconds
# done with pair (idx, jdx) (25, 7) in 0.3453710079193115 seconds
# done with pair (idx, jdx) (26, 0) in 0.018815040588378906 seconds
# done with pair (idx, jdx) (26, 1) in 0.03766298294067383 seconds
# done with pair (idx, jdx) (26, 2) in 0.05220603942871094 seconds
# done with pair (idx, jdx) (26, 3) in 0.08309197425842285 seconds
# done with pair (idx, jdx) (26, 4) in 0.1520230770111084 seconds
# done with pair (idx, jdx) (26, 5) in 0.2473599910736084 seconds
# done with pair (idx, jdx) (26, 6) in 0.3101499080657959 seconds
# done with pair (idx, jdx) (26, 7) in 0.3500537872314453 seconds
# done with pair (idx, jdx) (27, 0) in 0.01787424087524414 seconds
# done with pair (idx, jdx) (27, 1) in 0.0347440242767334 seconds
# done with pair (idx, jdx) (27, 2) in 0.05590009689331055 seconds
# done with pair (idx, jdx) (27, 3) in 0.07054519653320312 seconds
# done with pair (idx, jdx) (27, 4) in 0.15548396110534668 seconds
# done with pair (idx, jdx) (27, 5) in 0.23749613761901855 seconds
# done with pair (idx, jdx) (27, 6) in 0.275925874710083 seconds
# done with pair (idx, jdx) (27, 7) in 0.34113216400146484 seconds
# done with pair (idx, jdx) (28, 0) in 0.02439093589782715 seconds
# done with pair (idx, jdx) (28, 1) in 0.03889894485473633 seconds
# done with pair (idx, jdx) (28, 2) in 0.05669879913330078 seconds
# done with pair (idx, jdx) (28, 3) in 0.0668492317199707 seconds
# done with pair (idx, jdx) (28, 4) in 0.15527105331420898 seconds
# done with pair (idx, jdx) (28, 5) in 0.19602584838867188 seconds
# done with pair (idx, jdx) (28, 6) in 0.2875809669494629 seconds
# done with pair (idx, jdx) (28, 7) in 0.35422587394714355 seconds
# done with pair (idx, jdx) (29, 0) in 0.03432917594909668 seconds
# done with pair (idx, jdx) (29, 1) in 0.07015776634216309 seconds
# done with pair (idx, jdx) (29, 2) in 0.11798810958862305 seconds
# done with pair (idx, jdx) (29, 3) in 0.1218118667602539 seconds
# done with pair (idx, jdx) (29, 4) in 0.21704387664794922 seconds
# done with pair (idx, jdx) (29, 5) in 0.48004674911499023 seconds
# done with pair (idx, jdx) (29, 6) in 0.27104926109313965 seconds
# done with pair (idx, jdx) (29, 7) in 0.3958101272583008 seconds
# done with pair (idx, jdx) (30, 0) in 0.0400538444519043 seconds
# done with pair (idx, jdx) (30, 1) in 0.04537177085876465 seconds
# done with pair (idx, jdx) (30, 2) in 0.07433009147644043 seconds
# done with pair (idx, jdx) (30, 3) in 0.09008407592773438 seconds
# done with pair (idx, jdx) (30, 4) in 0.18130183219909668 seconds
# done with pair (idx, jdx) (30, 5) in 0.23249411582946777 seconds
# done with pair (idx, jdx) (30, 6) in 0.3625071048736572 seconds
# done with pair (idx, jdx) (30, 7) in 0.36522698402404785 seconds
# done with pair (idx, jdx) (31, 0) in 0.0212857723236084 seconds
# done with pair (idx, jdx) (31, 1) in 0.037548065185546875 seconds
# done with pair (idx, jdx) (31, 2) in 0.06173110008239746 seconds
# done with pair (idx, jdx) (31, 3) in 0.07359910011291504 seconds
# done with pair (idx, jdx) (31, 4) in 0.19378185272216797 seconds
# done with pair (idx, jdx) (31, 5) in 0.23057889938354492 seconds
# done with pair (idx, jdx) (31, 6) in 0.28548502922058105 seconds
# done with pair (idx, jdx) (31, 7) in 0.37868213653564453 seconds
# done with pair (idx, jdx) (32, 0) in 0.02818608283996582 seconds
# done with pair (idx, jdx) (32, 1) in 0.04137921333312988 seconds
# done with pair (idx, jdx) (32, 2) in 0.050074100494384766 seconds
# done with pair (idx, jdx) (32, 3) in 0.07126092910766602 seconds
# done with pair (idx, jdx) (32, 4) in 0.16286587715148926 seconds
# done with pair (idx, jdx) (32, 5) in 0.21483206748962402 seconds
# done with pair (idx, jdx) (32, 6) in 0.28977513313293457 seconds
# done with pair (idx, jdx) (32, 7) in 0.358644962310791 seconds
# done with pair (idx, jdx) (33, 0) in 0.02533888816833496 seconds
# done with pair (idx, jdx) (33, 1) in 0.047119855880737305 seconds
# done with pair (idx, jdx) (33, 2) in 0.062283992767333984 seconds
# done with pair (idx, jdx) (33, 3) in 0.09398126602172852 seconds
# done with pair (idx, jdx) (33, 4) in 0.1580359935760498 seconds
# done with pair (idx, jdx) (33, 5) in 0.21433281898498535 seconds
# done with pair (idx, jdx) (33, 6) in 0.28837108612060547 seconds
# done with pair (idx, jdx) (33, 7) in 0.3384699821472168 seconds
# done with pair (idx, jdx) (34, 0) in 0.026566743850708008 seconds
# done with pair (idx, jdx) (34, 1) in 0.044792890548706055 seconds
# done with pair (idx, jdx) (34, 2) in 0.05509305000305176 seconds
# done with pair (idx, jdx) (34, 3) in 0.07761383056640625 seconds
# done with pair (idx, jdx) (34, 4) in 0.12768888473510742 seconds
# done with pair (idx, jdx) (34, 5) in 0.22774505615234375 seconds
# done with pair (idx, jdx) (34, 6) in 0.26149988174438477 seconds
# done with pair (idx, jdx) (34, 7) in 0.3491389751434326 seconds
# done with pair (idx, jdx) (35, 0) in 0.0207979679107666 seconds
# done with pair (idx, jdx) (35, 1) in 0.03534984588623047 seconds
# done with pair (idx, jdx) (35, 2) in 0.06215214729309082 seconds
# done with pair (idx, jdx) (35, 3) in 0.08512306213378906 seconds
# done with pair (idx, jdx) (35, 4) in 0.1521599292755127 seconds
# done with pair (idx, jdx) (35, 5) in 0.20821475982666016 seconds
# done with pair (idx, jdx) (35, 6) in 0.280742883682251 seconds
# done with pair (idx, jdx) (35, 7) in 0.3522639274597168 seconds
# done with pair (idx, jdx) (36, 0) in 0.017235994338989258 seconds
# done with pair (idx, jdx) (36, 1) in 0.03824901580810547 seconds
# done with pair (idx, jdx) (36, 2) in 0.05859208106994629 seconds
# done with pair (idx, jdx) (36, 3) in 0.0770559310913086 seconds
# done with pair (idx, jdx) (36, 4) in 0.14769506454467773 seconds
# done with pair (idx, jdx) (36, 5) in 0.21390414237976074 seconds
# done with pair (idx, jdx) (36, 6) in 0.29828715324401855 seconds
# done with pair (idx, jdx) (36, 7) in 0.35001325607299805 seconds
# done with pair (idx, jdx) (37, 0) in 0.02616405487060547 seconds
# done with pair (idx, jdx) (37, 1) in 0.043070077896118164 seconds
# done with pair (idx, jdx) (37, 2) in 0.06293892860412598 seconds
# done with pair (idx, jdx) (37, 3) in 0.07392191886901855 seconds
# done with pair (idx, jdx) (37, 4) in 0.15733003616333008 seconds
# done with pair (idx, jdx) (37, 5) in 0.2294907569885254 seconds
# done with pair (idx, jdx) (37, 6) in 0.30510520935058594 seconds
# done with pair (idx, jdx) (37, 7) in 0.3525400161743164 seconds
# done with pair (idx, jdx) (38, 0) in 0.020932912826538086 seconds
# done with pair (idx, jdx) (38, 1) in 0.034407854080200195 seconds
# done with pair (idx, jdx) (38, 2) in 0.051733970642089844 seconds
# done with pair (idx, jdx) (38, 3) in 0.07068204879760742 seconds
# done with pair (idx, jdx) (38, 4) in 0.1455378532409668 seconds
# done with pair (idx, jdx) (38, 5) in 0.2367229461669922 seconds
# done with pair (idx, jdx) (38, 6) in 0.2953329086303711 seconds
# done with pair (idx, jdx) (38, 7) in 0.3368058204650879 seconds
# done with pair (idx, jdx) (39, 0) in 0.020901918411254883 seconds
# done with pair (idx, jdx) (39, 1) in 0.042612314224243164 seconds
# done with pair (idx, jdx) (39, 2) in 0.060745954513549805 seconds
# done with pair (idx, jdx) (39, 3) in 0.0900261402130127 seconds
# done with pair (idx, jdx) (39, 4) in 0.15519380569458008 seconds
# done with pair (idx, jdx) (39, 5) in 0.21051907539367676 seconds
# done with pair (idx, jdx) (39, 6) in 0.2734959125518799 seconds
# done with pair (idx, jdx) (39, 7) in 0.3518550395965576 seconds
# done with pair (idx, jdx) (40, 0) in 0.022576332092285156 seconds
# done with pair (idx, jdx) (40, 1) in 0.037011146545410156 seconds
# done with pair (idx, jdx) (40, 2) in 0.05813097953796387 seconds
# done with pair (idx, jdx) (40, 3) in 0.07806897163391113 seconds
# done with pair (idx, jdx) (40, 4) in 0.14066004753112793 seconds
# done with pair (idx, jdx) (40, 5) in 0.21187806129455566 seconds
# done with pair (idx, jdx) (40, 6) in 0.28076720237731934 seconds
# done with pair (idx, jdx) (40, 7) in 0.32184815406799316 seconds
# done with pair (idx, jdx) (41, 0) in 0.018289804458618164 seconds
# done with pair (idx, jdx) (41, 1) in 0.034906864166259766 seconds
# done with pair (idx, jdx) (41, 2) in 0.05269312858581543 seconds
# done with pair (idx, jdx) (41, 3) in 0.07027101516723633 seconds
# done with pair (idx, jdx) (41, 4) in 0.14621901512145996 seconds
# done with pair (idx, jdx) (41, 5) in 0.21020221710205078 seconds
# done with pair (idx, jdx) (41, 6) in 0.26972413063049316 seconds
# done with pair (idx, jdx) (41, 7) in 0.32185912132263184 seconds
# done with pair (idx, jdx) (42, 0) in 0.024284839630126953 seconds
# done with pair (idx, jdx) (42, 1) in 0.041062116622924805 seconds
# done with pair (idx, jdx) (42, 2) in 0.04893016815185547 seconds
# done with pair (idx, jdx) (42, 3) in 0.06630301475524902 seconds
# done with pair (idx, jdx) (42, 4) in 0.14568686485290527 seconds
# done with pair (idx, jdx) (42, 5) in 0.19623780250549316 seconds
# done with pair (idx, jdx) (42, 6) in 0.28423404693603516 seconds
# done with pair (idx, jdx) (42, 7) in 0.3656949996948242 seconds
# done with pair (idx, jdx) (43, 0) in 0.02735280990600586 seconds
# done with pair (idx, jdx) (43, 1) in 0.04180502891540527 seconds
# done with pair (idx, jdx) (43, 2) in 0.05782794952392578 seconds
# done with pair (idx, jdx) (43, 3) in 0.0939478874206543 seconds
# done with pair (idx, jdx) (43, 4) in 0.15120601654052734 seconds
# done with pair (idx, jdx) (43, 5) in 0.32472968101501465 seconds
# done with pair (idx, jdx) (43, 6) in 0.29597997665405273 seconds
# done with pair (idx, jdx) (43, 7) in 0.35642409324645996 seconds
# done with pair (idx, jdx) (44, 0) in 0.02368903160095215 seconds
# done with pair (idx, jdx) (44, 1) in 0.043749094009399414 seconds
# done with pair (idx, jdx) (44, 2) in 0.05247688293457031 seconds
# done with pair (idx, jdx) (44, 3) in 0.08178114891052246 seconds
# done with pair (idx, jdx) (44, 4) in 0.17446613311767578 seconds
# done with pair (idx, jdx) (44, 5) in 0.2538299560546875 seconds
# done with pair (idx, jdx) (44, 6) in 0.31232404708862305 seconds
# done with pair (idx, jdx) (44, 7) in 0.38095593452453613 seconds
# done with pair (idx, jdx) (45, 0) in 0.023669958114624023 seconds
# done with pair (idx, jdx) (45, 1) in 0.039536237716674805 seconds
# done with pair (idx, jdx) (45, 2) in 0.05195498466491699 seconds
# done with pair (idx, jdx) (45, 3) in 0.0657956600189209 seconds
# done with pair (idx, jdx) (45, 4) in 0.16048216819763184 seconds
# done with pair (idx, jdx) (45, 5) in 0.22571921348571777 seconds
# done with pair (idx, jdx) (45, 6) in 0.32958173751831055 seconds
# done with pair (idx, jdx) (45, 7) in 0.35335707664489746 seconds
# done with pair (idx, jdx) (46, 0) in 0.02174067497253418 seconds
# done with pair (idx, jdx) (46, 1) in 0.03616595268249512 seconds
# done with pair (idx, jdx) (46, 2) in 0.04933786392211914 seconds
# done with pair (idx, jdx) (46, 3) in 0.06656002998352051 seconds
# done with pair (idx, jdx) (46, 4) in 0.15351486206054688 seconds
# done with pair (idx, jdx) (46, 5) in 0.20369505882263184 seconds
# done with pair (idx, jdx) (46, 6) in 0.31377100944519043 seconds
# done with pair (idx, jdx) (46, 7) in 0.35623693466186523 seconds
# done with pair (idx, jdx) (47, 0) in 0.022024154663085938 seconds
# done with pair (idx, jdx) (47, 1) in 0.03469681739807129 seconds
# done with pair (idx, jdx) (47, 2) in 0.04874086380004883 seconds
# done with pair (idx, jdx) (47, 3) in 0.07833695411682129 seconds
# done with pair (idx, jdx) (47, 4) in 0.16830778121948242 seconds
# done with pair (idx, jdx) (47, 5) in 0.21206307411193848 seconds
# done with pair (idx, jdx) (47, 6) in 0.31736016273498535 seconds
# done with pair (idx, jdx) (47, 7) in 0.356353759765625 seconds
# done with pair (idx, jdx) (48, 0) in 0.022806167602539062 seconds
# done with pair (idx, jdx) (48, 1) in 0.06146979331970215 seconds
# done with pair (idx, jdx) (48, 2) in 0.09393119812011719 seconds
# done with pair (idx, jdx) (48, 3) in 0.08830904960632324 seconds
# done with pair (idx, jdx) (48, 4) in 0.15325212478637695 seconds
# done with pair (idx, jdx) (48, 5) in 0.21746277809143066 seconds
# done with pair (idx, jdx) (48, 6) in 0.29014015197753906 seconds
# done with pair (idx, jdx) (48, 7) in 0.3339877128601074 seconds
# done with pair (idx, jdx) (49, 0) in 0.023767948150634766 seconds
# done with pair (idx, jdx) (49, 1) in 0.0415189266204834 seconds
# done with pair (idx, jdx) (49, 2) in 0.056771039962768555 seconds
# done with pair (idx, jdx) (49, 3) in 0.1108250617980957 seconds
# done with pair (idx, jdx) (49, 4) in 0.15156888961791992 seconds
# done with pair (idx, jdx) (49, 5) in 0.221113920211792 seconds
# done with pair (idx, jdx) (49, 6) in 0.31053733825683594 seconds
# done with pair (idx, jdx) (49, 7) in 0.36801886558532715 seconds
# done with pair (idx, jdx) (50, 0) in 0.018580913543701172 seconds
# done with pair (idx, jdx) (50, 1) in 0.036277055740356445 seconds
# done with pair (idx, jdx) (50, 2) in 0.05445599555969238 seconds
# done with pair (idx, jdx) (50, 3) in 0.07213902473449707 seconds
# done with pair (idx, jdx) (50, 4) in 0.14937686920166016 seconds
# done with pair (idx, jdx) (50, 5) in 0.20743703842163086 seconds
# done with pair (idx, jdx) (50, 6) in 0.2825169563293457 seconds
# done with pair (idx, jdx) (50, 7) in 0.32667112350463867 seconds
# done with pair (idx, jdx) (51, 0) in 0.019115924835205078 seconds
# done with pair (idx, jdx) (51, 1) in 0.03293490409851074 seconds
# done with pair (idx, jdx) (51, 2) in 0.04878592491149902 seconds
# done with pair (idx, jdx) (51, 3) in 0.08281111717224121 seconds
# done with pair (idx, jdx) (51, 4) in 0.1558849811553955 seconds
# done with pair (idx, jdx) (51, 5) in 0.20519709587097168 seconds
# done with pair (idx, jdx) (51, 6) in 0.2731752395629883 seconds
# done with pair (idx, jdx) (51, 7) in 0.3483889102935791 seconds
# done with pair (idx, jdx) (52, 0) in 0.01753711700439453 seconds
# done with pair (idx, jdx) (52, 1) in 0.0320892333984375 seconds
# done with pair (idx, jdx) (52, 2) in 0.05078315734863281 seconds
# done with pair (idx, jdx) (52, 3) in 0.07078194618225098 seconds
# done with pair (idx, jdx) (52, 4) in 0.13336610794067383 seconds
# done with pair (idx, jdx) (52, 5) in 0.195479154586792 seconds
# done with pair (idx, jdx) (52, 6) in 0.2884030342102051 seconds
# done with pair (idx, jdx) (52, 7) in 0.34450721740722656 seconds
# done with pair (idx, jdx) (53, 0) in 0.025997638702392578 seconds
# done with pair (idx, jdx) (53, 1) in 0.04638791084289551 seconds
# done with pair (idx, jdx) (53, 2) in 0.05463719367980957 seconds
# done with pair (idx, jdx) (53, 3) in 0.06822609901428223 seconds
# done with pair (idx, jdx) (53, 4) in 0.15552067756652832 seconds
# done with pair (idx, jdx) (53, 5) in 0.21459078788757324 seconds
# done with pair (idx, jdx) (53, 6) in 0.3091909885406494 seconds
# done with pair (idx, jdx) (53, 7) in 0.39043593406677246 seconds
# done with pair (idx, jdx) (54, 0) in 0.023295164108276367 seconds
# done with pair (idx, jdx) (54, 1) in 0.03825688362121582 seconds
# done with pair (idx, jdx) (54, 2) in 0.05148601531982422 seconds
# done with pair (idx, jdx) (54, 3) in 0.07058000564575195 seconds
# done with pair (idx, jdx) (54, 4) in 0.18035268783569336 seconds
# done with pair (idx, jdx) (54, 5) in 0.2034759521484375 seconds
# done with pair (idx, jdx) (54, 6) in 0.28882598876953125 seconds
# done with pair (idx, jdx) (54, 7) in 0.37250614166259766 seconds
# done with pair (idx, jdx) (55, 0) in 0.02138495445251465 seconds
# done with pair (idx, jdx) (55, 1) in 0.04122304916381836 seconds
# done with pair (idx, jdx) (55, 2) in 0.04730701446533203 seconds
# done with pair (idx, jdx) (55, 3) in 0.08545398712158203 seconds
# done with pair (idx, jdx) (55, 4) in 0.16539907455444336 seconds
# done with pair (idx, jdx) (55, 5) in 0.21392607688903809 seconds
# done with pair (idx, jdx) (55, 6) in 0.2869241237640381 seconds
# done with pair (idx, jdx) (55, 7) in 0.3288309574127197 seconds
# done with pair (idx, jdx) (56, 0) in 0.021500825881958008 seconds
# done with pair (idx, jdx) (56, 1) in 0.036872148513793945 seconds
# done with pair (idx, jdx) (56, 2) in 0.06655716896057129 seconds
# done with pair (idx, jdx) (56, 3) in 0.08882808685302734 seconds
# done with pair (idx, jdx) (56, 4) in 0.13228607177734375 seconds
# done with pair (idx, jdx) (56, 5) in 0.2344040870666504 seconds
# done with pair (idx, jdx) (56, 6) in 0.27314090728759766 seconds
# done with pair (idx, jdx) (56, 7) in 0.3416872024536133 seconds
# done with pair (idx, jdx) (57, 0) in 0.024205923080444336 seconds
# done with pair (idx, jdx) (57, 1) in 0.04330873489379883 seconds
# done with pair (idx, jdx) (57, 2) in 0.05608987808227539 seconds
# done with pair (idx, jdx) (57, 3) in 0.07479000091552734 seconds
# done with pair (idx, jdx) (57, 4) in 0.1459789276123047 seconds
# done with pair (idx, jdx) (57, 5) in 0.203826904296875 seconds
# done with pair (idx, jdx) (57, 6) in 0.25630998611450195 seconds
# done with pair (idx, jdx) (57, 7) in 0.35134196281433105 seconds
# done with pair (idx, jdx) (58, 0) in 0.03511404991149902 seconds
# done with pair (idx, jdx) (58, 1) in 0.050888776779174805 seconds
# done with pair (idx, jdx) (58, 2) in 0.0709230899810791 seconds
# done with pair (idx, jdx) (58, 3) in 0.07850384712219238 seconds
# done with pair (idx, jdx) (58, 4) in 0.13692402839660645 seconds
# done with pair (idx, jdx) (58, 5) in 0.19930100440979004 seconds
# done with pair (idx, jdx) (58, 6) in 0.2742471694946289 seconds
# done with pair (idx, jdx) (58, 7) in 0.3446519374847412 seconds
# done with pair (idx, jdx) (59, 0) in 0.019257068634033203 seconds
# done with pair (idx, jdx) (59, 1) in 0.035279035568237305 seconds
# done with pair (idx, jdx) (59, 2) in 0.051531076431274414 seconds
# done with pair (idx, jdx) (59, 3) in 0.06985688209533691 seconds
# done with pair (idx, jdx) (59, 4) in 0.14861679077148438 seconds
# done with pair (idx, jdx) (59, 5) in 0.1886000633239746 seconds
# done with pair (idx, jdx) (59, 6) in 0.285006046295166 seconds
# done with pair (idx, jdx) (59, 7) in 0.37706613540649414 seconds
# done with pair (idx, jdx) (60, 0) in 0.0227358341217041 seconds
# done with pair (idx, jdx) (60, 1) in 0.046002864837646484 seconds
# done with pair (idx, jdx) (60, 2) in 0.057641029357910156 seconds
# done with pair (idx, jdx) (60, 3) in 0.08647966384887695 seconds
# done with pair (idx, jdx) (60, 4) in 0.14227795600891113 seconds
# done with pair (idx, jdx) (60, 5) in 0.2198789119720459 seconds
# done with pair (idx, jdx) (60, 6) in 0.31223607063293457 seconds
# done with pair (idx, jdx) (60, 7) in 0.3359038829803467 seconds
# done with pair (idx, jdx) (61, 0) in 0.019834041595458984 seconds
# done with pair (idx, jdx) (61, 1) in 0.03306126594543457 seconds
# done with pair (idx, jdx) (61, 2) in 0.06607794761657715 seconds
# done with pair (idx, jdx) (61, 3) in 0.09144282341003418 seconds
# done with pair (idx, jdx) (61, 4) in 0.13424992561340332 seconds
# done with pair (idx, jdx) (61, 5) in 0.2094249725341797 seconds
# done with pair (idx, jdx) (61, 6) in 0.27115583419799805 seconds
# done with pair (idx, jdx) (61, 7) in 0.33457374572753906 seconds
# done with pair (idx, jdx) (62, 0) in 0.020627975463867188 seconds
# done with pair (idx, jdx) (62, 1) in 0.03747200965881348 seconds
# done with pair (idx, jdx) (62, 2) in 0.05453896522521973 seconds
# done with pair (idx, jdx) (62, 3) in 0.10786795616149902 seconds
# done with pair (idx, jdx) (62, 4) in 0.14702105522155762 seconds
# done with pair (idx, jdx) (62, 5) in 0.20660614967346191 seconds
# done with pair (idx, jdx) (62, 6) in 0.2635951042175293 seconds
# done with pair (idx, jdx) (62, 7) in 0.46494221687316895 seconds
# done with pair (idx, jdx) (63, 0) in 0.02433490753173828 seconds
# done with pair (idx, jdx) (63, 1) in 0.0476531982421875 seconds
# done with pair (idx, jdx) (63, 2) in 0.06977009773254395 seconds
# done with pair (idx, jdx) (63, 3) in 0.08268427848815918 seconds
# done with pair (idx, jdx) (63, 4) in 0.21464991569519043 seconds
# done with pair (idx, jdx) (63, 5) in 0.3518788814544678 seconds
# done with pair (idx, jdx) (63, 6) in 0.30048680305480957 seconds
# done with pair (idx, jdx) (63, 7) in 0.3598310947418213 seconds
# done with pair (idx, jdx) (64, 0) in 0.020107746124267578 seconds
# done with pair (idx, jdx) (64, 1) in 0.03277897834777832 seconds
# done with pair (idx, jdx) (64, 2) in 0.05115985870361328 seconds
# done with pair (idx, jdx) (64, 3) in 0.07048892974853516 seconds
# done with pair (idx, jdx) (64, 4) in 0.15848994255065918 seconds
# done with pair (idx, jdx) (64, 5) in 0.23051810264587402 seconds
# done with pair (idx, jdx) (64, 6) in 0.303774356842041 seconds
# done with pair (idx, jdx) (64, 7) in 0.364063024520874 seconds
# done with pair (idx, jdx) (65, 0) in 0.017594099044799805 seconds
# done with pair (idx, jdx) (65, 1) in 0.03495001792907715 seconds
# done with pair (idx, jdx) (65, 2) in 0.05652284622192383 seconds
# done with pair (idx, jdx) (65, 3) in 0.06540107727050781 seconds
# done with pair (idx, jdx) (65, 4) in 0.15231609344482422 seconds
# done with pair (idx, jdx) (65, 5) in 0.23190593719482422 seconds
# done with pair (idx, jdx) (65, 6) in 0.2913179397583008 seconds
# done with pair (idx, jdx) (65, 7) in 0.3464350700378418 seconds
# done with pair (idx, jdx) (66, 0) in 0.020073890686035156 seconds
# done with pair (idx, jdx) (66, 1) in 0.03882098197937012 seconds
# done with pair (idx, jdx) (66, 2) in 0.05349993705749512 seconds
# done with pair (idx, jdx) (66, 3) in 0.0655069351196289 seconds
# done with pair (idx, jdx) (66, 4) in 0.15716123580932617 seconds
# done with pair (idx, jdx) (66, 5) in 0.19066286087036133 seconds
# done with pair (idx, jdx) (66, 6) in 0.27451276779174805 seconds
# done with pair (idx, jdx) (66, 7) in 0.32775402069091797 seconds
# done with pair (idx, jdx) (67, 0) in 0.025806903839111328 seconds
# done with pair (idx, jdx) (67, 1) in 0.03477621078491211 seconds
# done with pair (idx, jdx) (67, 2) in 0.04845118522644043 seconds
# done with pair (idx, jdx) (67, 3) in 0.07476401329040527 seconds
# done with pair (idx, jdx) (67, 4) in 0.14658212661743164 seconds
# done with pair (idx, jdx) (67, 5) in 0.23210787773132324 seconds
# done with pair (idx, jdx) (67, 6) in 0.3038010597229004 seconds
# done with pair (idx, jdx) (67, 7) in 0.3759579658508301 seconds
# done with pair (idx, jdx) (68, 0) in 0.02099299430847168 seconds
# done with pair (idx, jdx) (68, 1) in 0.03594207763671875 seconds
# done with pair (idx, jdx) (68, 2) in 0.06185507774353027 seconds
# done with pair (idx, jdx) (68, 3) in 0.07694005966186523 seconds
# done with pair (idx, jdx) (68, 4) in 0.17614412307739258 seconds
# done with pair (idx, jdx) (68, 5) in 0.19692635536193848 seconds
# done with pair (idx, jdx) (68, 6) in 0.2822990417480469 seconds
# done with pair (idx, jdx) (68, 7) in 0.36057305335998535 seconds
# done with pair (idx, jdx) (69, 0) in 0.019222021102905273 seconds
# done with pair (idx, jdx) (69, 1) in 0.03362917900085449 seconds
# done with pair (idx, jdx) (69, 2) in 0.04652690887451172 seconds
# done with pair (idx, jdx) (69, 3) in 0.06466817855834961 seconds
# done with pair (idx, jdx) (69, 4) in 0.14158892631530762 seconds
# done with pair (idx, jdx) (69, 5) in 0.21639394760131836 seconds
# done with pair (idx, jdx) (69, 6) in 0.28814005851745605 seconds
# done with pair (idx, jdx) (69, 7) in 0.3520989418029785 seconds
# done with pair (idx, jdx) (70, 0) in 0.02401566505432129 seconds
# done with pair (idx, jdx) (70, 1) in 0.0527191162109375 seconds
# done with pair (idx, jdx) (70, 2) in 0.06179404258728027 seconds
# done with pair (idx, jdx) (70, 3) in 0.08266377449035645 seconds
# done with pair (idx, jdx) (70, 4) in 0.1549849510192871 seconds
# done with pair (idx, jdx) (70, 5) in 0.20551609992980957 seconds
# done with pair (idx, jdx) (70, 6) in 0.26993608474731445 seconds
# done with pair (idx, jdx) (70, 7) in 0.35935401916503906 seconds
# done with pair (idx, jdx) (71, 0) in 0.02025604248046875 seconds
# done with pair (idx, jdx) (71, 1) in 0.04467892646789551 seconds
# done with pair (idx, jdx) (71, 2) in 0.05348920822143555 seconds
# done with pair (idx, jdx) (71, 3) in 0.06697607040405273 seconds
# done with pair (idx, jdx) (71, 4) in 0.1769571304321289 seconds
# done with pair (idx, jdx) (71, 5) in 0.21940279006958008 seconds
# done with pair (idx, jdx) (71, 6) in 0.29613399505615234 seconds
# done with pair (idx, jdx) (71, 7) in 0.34991931915283203 seconds
# done with pair (idx, jdx) (72, 0) in 0.016544103622436523 seconds
# done with pair (idx, jdx) (72, 1) in 0.03368687629699707 seconds
# done with pair (idx, jdx) (72, 2) in 0.05513811111450195 seconds
# done with pair (idx, jdx) (72, 3) in 0.07346796989440918 seconds
# done with pair (idx, jdx) (72, 4) in 0.1475679874420166 seconds
# done with pair (idx, jdx) (72, 5) in 0.26531100273132324 seconds
# done with pair (idx, jdx) (72, 6) in 0.26215028762817383 seconds
# done with pair (idx, jdx) (72, 7) in 0.32442212104797363 seconds
# done with pair (idx, jdx) (73, 0) in 0.016569852828979492 seconds
# done with pair (idx, jdx) (73, 1) in 0.030750036239624023 seconds
# done with pair (idx, jdx) (73, 2) in 0.04788994789123535 seconds
# done with pair (idx, jdx) (73, 3) in 0.06794595718383789 seconds
# done with pair (idx, jdx) (73, 4) in 0.16237998008728027 seconds
# done with pair (idx, jdx) (73, 5) in 0.22164106369018555 seconds
# done with pair (idx, jdx) (73, 6) in 0.30266809463500977 seconds
# done with pair (idx, jdx) (73, 7) in 0.38779306411743164 seconds
# done with pair (idx, jdx) (74, 0) in 0.038877010345458984 seconds
# done with pair (idx, jdx) (74, 1) in 0.06863903999328613 seconds
# done with pair (idx, jdx) (74, 2) in 0.07187604904174805 seconds
# done with pair (idx, jdx) (74, 3) in 0.09328389167785645 seconds
# done with pair (idx, jdx) (74, 4) in 0.15906023979187012 seconds
# done with pair (idx, jdx) (74, 5) in 0.21795105934143066 seconds
# done with pair (idx, jdx) (74, 6) in 0.2852811813354492 seconds
# done with pair (idx, jdx) (74, 7) in 0.3511028289794922 seconds
# done with pair (idx, jdx) (75, 0) in 0.02022409439086914 seconds
# done with pair (idx, jdx) (75, 1) in 0.03470802307128906 seconds
# done with pair (idx, jdx) (75, 2) in 0.051872968673706055 seconds
# done with pair (idx, jdx) (75, 3) in 0.07354974746704102 seconds
# done with pair (idx, jdx) (75, 4) in 0.1527559757232666 seconds
# done with pair (idx, jdx) (75, 5) in 0.21552014350891113 seconds
# done with pair (idx, jdx) (75, 6) in 0.29033660888671875 seconds
# done with pair (idx, jdx) (75, 7) in 0.3521242141723633 seconds
# done with pair (idx, jdx) (76, 0) in 0.016610145568847656 seconds
# done with pair (idx, jdx) (76, 1) in 0.032813072204589844 seconds
# done with pair (idx, jdx) (76, 2) in 0.05196213722229004 seconds
# done with pair (idx, jdx) (76, 3) in 0.07806992530822754 seconds
# done with pair (idx, jdx) (76, 4) in 0.14606022834777832 seconds
# done with pair (idx, jdx) (76, 5) in 0.21884894371032715 seconds
# done with pair (idx, jdx) (76, 6) in 0.29604411125183105 seconds
# done with pair (idx, jdx) (76, 7) in 0.42146897315979004 seconds
# done with pair (idx, jdx) (77, 0) in 0.033959150314331055 seconds
# done with pair (idx, jdx) (77, 1) in 0.04460501670837402 seconds
# done with pair (idx, jdx) (77, 2) in 0.07305097579956055 seconds
# done with pair (idx, jdx) (77, 3) in 0.12770295143127441 seconds
# done with pair (idx, jdx) (77, 4) in 0.1591639518737793 seconds
# done with pair (idx, jdx) (77, 5) in 0.22386598587036133 seconds
# done with pair (idx, jdx) (77, 6) in 0.3296518325805664 seconds
# done with pair (idx, jdx) (77, 7) in 0.38515496253967285 seconds
# done with pair (idx, jdx) (78, 0) in 0.017290830612182617 seconds
# done with pair (idx, jdx) (78, 1) in 0.03186321258544922 seconds
# done with pair (idx, jdx) (78, 2) in 0.050225019454956055 seconds
# done with pair (idx, jdx) (78, 3) in 0.07335090637207031 seconds
# done with pair (idx, jdx) (78, 4) in 0.15349769592285156 seconds
# done with pair (idx, jdx) (78, 5) in 0.19949007034301758 seconds
# done with pair (idx, jdx) (78, 6) in 0.27544498443603516 seconds
# done with pair (idx, jdx) (78, 7) in 0.3251049518585205 seconds
# done with pair (idx, jdx) (79, 0) in 0.028081893920898438 seconds
# done with pair (idx, jdx) (79, 1) in 0.035768747329711914 seconds
# done with pair (idx, jdx) (79, 2) in 0.05194497108459473 seconds
# done with pair (idx, jdx) (79, 3) in 0.07118701934814453 seconds
# done with pair (idx, jdx) (79, 4) in 0.14044404029846191 seconds
# done with pair (idx, jdx) (79, 5) in 0.22677922248840332 seconds
# done with pair (idx, jdx) (79, 6) in 0.3196380138397217 seconds
# done with pair (idx, jdx) (79, 7) in 0.34673023223876953 seconds
# done with pair (idx, jdx) (80, 0) in 0.01777815818786621 seconds
# done with pair (idx, jdx) (80, 1) in 0.03646588325500488 seconds
# done with pair (idx, jdx) (80, 2) in 0.061241865158081055 seconds
# done with pair (idx, jdx) (80, 3) in 0.06981301307678223 seconds
# done with pair (idx, jdx) (80, 4) in 0.15532922744750977 seconds
# done with pair (idx, jdx) (80, 5) in 0.18437719345092773 seconds
# done with pair (idx, jdx) (80, 6) in 0.2666590213775635 seconds
# done with pair (idx, jdx) (80, 7) in 0.34415483474731445 seconds
# done with pair (idx, jdx) (81, 0) in 0.02144598960876465 seconds
# done with pair (idx, jdx) (81, 1) in 0.03860878944396973 seconds
# done with pair (idx, jdx) (81, 2) in 0.1257641315460205 seconds
# done with pair (idx, jdx) (81, 3) in 0.2958638668060303 seconds
# done with pair (idx, jdx) (81, 4) in 0.281400203704834 seconds
# done with pair (idx, jdx) (81, 5) in 0.21455788612365723 seconds
# done with pair (idx, jdx) (81, 6) in 0.2797279357910156 seconds
# done with pair (idx, jdx) (81, 7) in 0.32172298431396484 seconds
# done with pair (idx, jdx) (82, 0) in 0.019855976104736328 seconds
# done with pair (idx, jdx) (82, 1) in 0.04334688186645508 seconds
# done with pair (idx, jdx) (82, 2) in 0.06693482398986816 seconds
# done with pair (idx, jdx) (82, 3) in 0.06802988052368164 seconds
# done with pair (idx, jdx) (82, 4) in 0.1430220603942871 seconds
# done with pair (idx, jdx) (82, 5) in 0.19459199905395508 seconds
# done with pair (idx, jdx) (82, 6) in 0.2651081085205078 seconds
# done with pair (idx, jdx) (82, 7) in 0.48738574981689453 seconds
# done with pair (idx, jdx) (83, 0) in 0.01980876922607422 seconds
# done with pair (idx, jdx) (83, 1) in 0.03429889678955078 seconds
# done with pair (idx, jdx) (83, 2) in 0.09528326988220215 seconds
# done with pair (idx, jdx) (83, 3) in 0.1158289909362793 seconds
# done with pair (idx, jdx) (83, 4) in 0.13270092010498047 seconds
# done with pair (idx, jdx) (83, 5) in 0.21565794944763184 seconds
# done with pair (idx, jdx) (83, 6) in 0.2706620693206787 seconds
# done with pair (idx, jdx) (83, 7) in 0.32885098457336426 seconds
# done with pair (idx, jdx) (84, 0) in 0.0261080265045166 seconds
# done with pair (idx, jdx) (84, 1) in 0.03261113166809082 seconds
# done with pair (idx, jdx) (84, 2) in 0.05223703384399414 seconds
# done with pair (idx, jdx) (84, 3) in 0.06708407402038574 seconds
# done with pair (idx, jdx) (84, 4) in 0.3172440528869629 seconds
# done with pair (idx, jdx) (84, 5) in 0.29823803901672363 seconds
# done with pair (idx, jdx) (84, 6) in 0.3299899101257324 seconds
# done with pair (idx, jdx) (84, 7) in 0.39727210998535156 seconds
# done with pair (idx, jdx) (85, 0) in 0.02480792999267578 seconds
# done with pair (idx, jdx) (85, 1) in 0.06165504455566406 seconds
# done with pair (idx, jdx) (85, 2) in 0.06025815010070801 seconds
# done with pair (idx, jdx) (85, 3) in 0.10016393661499023 seconds
# done with pair (idx, jdx) (85, 4) in 0.17763304710388184 seconds
# done with pair (idx, jdx) (85, 5) in 0.2316269874572754 seconds
# done with pair (idx, jdx) (85, 6) in 0.2921268939971924 seconds
# done with pair (idx, jdx) (85, 7) in 0.37190794944763184 seconds
# done with pair (idx, jdx) (86, 0) in 0.020291805267333984 seconds
# done with pair (idx, jdx) (86, 1) in 0.04101204872131348 seconds
# done with pair (idx, jdx) (86, 2) in 0.05178403854370117 seconds
# done with pair (idx, jdx) (86, 3) in 0.08082723617553711 seconds
# done with pair (idx, jdx) (86, 4) in 0.17303776741027832 seconds
# done with pair (idx, jdx) (86, 5) in 0.3004729747772217 seconds
# done with pair (idx, jdx) (86, 6) in 0.3996238708496094 seconds
# done with pair (idx, jdx) (86, 7) in 0.5366189479827881 seconds
# done with pair (idx, jdx) (87, 0) in 0.023076772689819336 seconds
# done with pair (idx, jdx) (87, 1) in 0.03297615051269531 seconds
# done with pair (idx, jdx) (87, 2) in 0.0481259822845459 seconds
# done with pair (idx, jdx) (87, 3) in 0.08816909790039062 seconds
# done with pair (idx, jdx) (87, 4) in 0.17412924766540527 seconds
# done with pair (idx, jdx) (87, 5) in 0.22829318046569824 seconds
# done with pair (idx, jdx) (87, 6) in 0.3273310661315918 seconds
# done with pair (idx, jdx) (87, 7) in 0.35517287254333496 seconds
# done with pair (idx, jdx) (88, 0) in 0.02352285385131836 seconds
# done with pair (idx, jdx) (88, 1) in 0.04190492630004883 seconds
# done with pair (idx, jdx) (88, 2) in 0.05700826644897461 seconds
# done with pair (idx, jdx) (88, 3) in 0.07929706573486328 seconds
# done with pair (idx, jdx) (88, 4) in 0.15952205657958984 seconds
# done with pair (idx, jdx) (88, 5) in 0.20684123039245605 seconds
# done with pair (idx, jdx) (88, 6) in 0.2766239643096924 seconds
# done with pair (idx, jdx) (88, 7) in 0.3676879405975342 seconds
# done with pair (idx, jdx) (89, 0) in 0.03417491912841797 seconds
# done with pair (idx, jdx) (89, 1) in 0.03507494926452637 seconds
# done with pair (idx, jdx) (89, 2) in 0.059676170349121094 seconds
# done with pair (idx, jdx) (89, 3) in 0.07685112953186035 seconds
# done with pair (idx, jdx) (89, 4) in 0.1542820930480957 seconds
# done with pair (idx, jdx) (89, 5) in 0.23955583572387695 seconds
# done with pair (idx, jdx) (89, 6) in 0.3415186405181885 seconds
# done with pair (idx, jdx) (89, 7) in 0.49519991874694824 seconds
# done with pair (idx, jdx) (90, 0) in 0.029042959213256836 seconds
# done with pair (idx, jdx) (90, 1) in 0.053029775619506836 seconds
# done with pair (idx, jdx) (90, 2) in 0.11935591697692871 seconds
# done with pair (idx, jdx) (90, 3) in 0.13814210891723633 seconds
# done with pair (idx, jdx) (90, 4) in 0.3036930561065674 seconds
# done with pair (idx, jdx) (90, 5) in 0.44248390197753906 seconds
# done with pair (idx, jdx) (90, 6) in 0.38802194595336914 seconds
# done with pair (idx, jdx) (90, 7) in 0.3703169822692871 seconds
# done with pair (idx, jdx) (91, 0) in 0.02327704429626465 seconds
# done with pair (idx, jdx) (91, 1) in 0.03282284736633301 seconds
# done with pair (idx, jdx) (91, 2) in 0.052426815032958984 seconds
# done with pair (idx, jdx) (91, 3) in 0.06416797637939453 seconds
# done with pair (idx, jdx) (91, 4) in 0.14541316032409668 seconds
# done with pair (idx, jdx) (91, 5) in 0.193131685256958 seconds
# done with pair (idx, jdx) (91, 6) in 0.27422285079956055 seconds
# done with pair (idx, jdx) (91, 7) in 0.3354220390319824 seconds
# done with pair (idx, jdx) (92, 0) in 0.025003910064697266 seconds
# done with pair (idx, jdx) (92, 1) in 0.047943115234375 seconds
# done with pair (idx, jdx) (92, 2) in 0.056581974029541016 seconds
# done with pair (idx, jdx) (92, 3) in 0.09246993064880371 seconds
# done with pair (idx, jdx) (92, 4) in 0.15164804458618164 seconds
# done with pair (idx, jdx) (92, 5) in 0.23485493659973145 seconds
# done with pair (idx, jdx) (92, 6) in 0.28166818618774414 seconds
# done with pair (idx, jdx) (92, 7) in 0.3509330749511719 seconds
# done with pair (idx, jdx) (93, 0) in 0.017404794692993164 seconds
# done with pair (idx, jdx) (93, 1) in 0.035469770431518555 seconds
# done with pair (idx, jdx) (93, 2) in 0.05800294876098633 seconds
# done with pair (idx, jdx) (93, 3) in 0.06239008903503418 seconds
# done with pair (idx, jdx) (93, 4) in 0.14521312713623047 seconds
# done with pair (idx, jdx) (93, 5) in 0.19916081428527832 seconds
# done with pair (idx, jdx) (93, 6) in 0.2655370235443115 seconds
# done with pair (idx, jdx) (93, 7) in 0.327467679977417 seconds
# done with pair (idx, jdx) (94, 0) in 0.023270845413208008 seconds
# done with pair (idx, jdx) (94, 1) in 0.03615307807922363 seconds
# done with pair (idx, jdx) (94, 2) in 0.05620574951171875 seconds
# done with pair (idx, jdx) (94, 3) in 0.06545424461364746 seconds
# done with pair (idx, jdx) (94, 4) in 0.14978885650634766 seconds
# done with pair (idx, jdx) (94, 5) in 0.19048333168029785 seconds
# done with pair (idx, jdx) (94, 6) in 0.27158188819885254 seconds
# done with pair (idx, jdx) (94, 7) in 0.5373969078063965 seconds
# done with pair (idx, jdx) (95, 0) in 0.02518916130065918 seconds
# done with pair (idx, jdx) (95, 1) in 0.04821896553039551 seconds
# done with pair (idx, jdx) (95, 2) in 0.05643796920776367 seconds
# done with pair (idx, jdx) (95, 3) in 0.130997896194458 seconds
# done with pair (idx, jdx) (95, 4) in 0.14795398712158203 seconds
# done with pair (idx, jdx) (95, 5) in 0.21286797523498535 seconds
# done with pair (idx, jdx) (95, 6) in 0.30661797523498535 seconds
# done with pair (idx, jdx) (95, 7) in 0.38165879249572754 seconds
# done with pair (idx, jdx) (96, 0) in 0.04789090156555176 seconds
# done with pair (idx, jdx) (96, 1) in 0.0364537239074707 seconds
# done with pair (idx, jdx) (96, 2) in 0.15563082695007324 seconds
# done with pair (idx, jdx) (96, 3) in 0.07743096351623535 seconds
# done with pair (idx, jdx) (96, 4) in 0.14833903312683105 seconds
# done with pair (idx, jdx) (96, 5) in 0.376507043838501 seconds
# done with pair (idx, jdx) (96, 6) in 0.32263970375061035 seconds
# done with pair (idx, jdx) (96, 7) in 0.3507039546966553 seconds
# done with pair (idx, jdx) (97, 0) in 0.018340110778808594 seconds
# done with pair (idx, jdx) (97, 1) in 0.046536922454833984 seconds
# done with pair (idx, jdx) (97, 2) in 0.0594792366027832 seconds
# done with pair (idx, jdx) (97, 3) in 0.07272696495056152 seconds
# done with pair (idx, jdx) (97, 4) in 0.1474301815032959 seconds
# done with pair (idx, jdx) (97, 5) in 0.19936203956604004 seconds
# done with pair (idx, jdx) (97, 6) in 0.3195960521697998 seconds
# done with pair (idx, jdx) (97, 7) in 0.3633451461791992 seconds
# done with pair (idx, jdx) (98, 0) in 0.019035816192626953 seconds
# done with pair (idx, jdx) (98, 1) in 0.03539013862609863 seconds
# done with pair (idx, jdx) (98, 2) in 0.07105588912963867 seconds
# done with pair (idx, jdx) (98, 3) in 0.08215594291687012 seconds
# done with pair (idx, jdx) (98, 4) in 0.14508914947509766 seconds
# done with pair (idx, jdx) (98, 5) in 0.22146892547607422 seconds
# done with pair (idx, jdx) (98, 6) in 0.31937289237976074 seconds
# done with pair (idx, jdx) (98, 7) in 0.37185096740722656 seconds
# done with pair (idx, jdx) (99, 0) in 0.023859024047851562 seconds
# done with pair (idx, jdx) (99, 1) in 0.04290413856506348 seconds
# done with pair (idx, jdx) (99, 2) in 0.052731990814208984 seconds
# done with pair (idx, jdx) (99, 3) in 0.08143782615661621 seconds
# done with pair (idx, jdx) (99, 4) in 0.15641403198242188 seconds
# done with pair (idx, jdx) (99, 5) in 0.21544480323791504 seconds
# done with pair (idx, jdx) (99, 6) in 0.2980349063873291 seconds
# done with pair (idx, jdx) (99, 7) in 0.3683960437774658 seconds

# %%
np.median(error_lspi, axis=0)
# Out:
# array([ 0.34243106,  0.22264834,  0.17188926,  0.14500774,  0.10292338,
#         0.08007318,  0.07379356,  0.06435294])

# %%
data_lspi_dis = np.zeros((n_trials, len(NT_values)))
data_lspi_avg = np.zeros((n_trials, len(NT_values)))

loop_start = time.time()
for idx, traj in enumerate(all_trajectories):
    for jdx, NT_value in enumerate(NT_values):
        
        iter_start = time.time()
        sample = traj[:NT_value]

        try:
            K_lspi, cost_lspi_dis = lspi(prob, sample, K0)
            # LSPI succeeded, so we can at least score the discounted
            data_lspi_dis[idx, jdx] = cost_lspi_dis
            
            # sanity
            assert np.allclose(
                prob.score(prob.solve_value_function(K_lspi, discount=True), discount=True),
                cost_lspi_dis)
            
            # now we try to score K_lspi on the avg cost
            try:
                Phat_lspi_avg = prob.solve_value_function(K_lspi, discount=False)
                data_lspi_avg[idx, jdx] = prob.score(Phat_lspi_avg, discount=False)
            except InstabilityException:
                # the discounted controller did not work for the true system
                data_lspi_avg[idx, jdx] = np.inf
            
        except InstabilityException:
            # if LSPI fails, both of them will score inf
            data_lspi_dis[idx, jdx] = np.inf
            data_lspi_avg[idx, jdx] = np.inf
            
        print("done with pair (idx, jdx)", (idx, jdx), "in {} seconds".format(time.time() - iter_start))
        
print("loop took", time.time() - loop_start, "seconds")
# Out:
# done with pair (idx, jdx) (0, 0) in 0.07462787628173828 seconds
# done with pair (idx, jdx) (0, 1) in 0.1343832015991211 seconds
# done with pair (idx, jdx) (0, 2) in 0.2755279541015625 seconds
# done with pair (idx, jdx) (0, 3) in 0.2826120853424072 seconds
# done with pair (idx, jdx) (0, 4) in 1.174226999282837 seconds
# done with pair (idx, jdx) (0, 5) in 1.5503978729248047 seconds
# done with pair (idx, jdx) (0, 6) in 2.006042957305908 seconds
# done with pair (idx, jdx) (0, 7) in 2.921441078186035 seconds
# done with pair (idx, jdx) (1, 0) in 0.11652874946594238 seconds
# done with pair (idx, jdx) (1, 1) in 0.309312105178833 seconds
# done with pair (idx, jdx) (1, 2) in 0.3037397861480713 seconds
# done with pair (idx, jdx) (1, 3) in 0.39354825019836426 seconds
# done with pair (idx, jdx) (1, 4) in 2.029719829559326 seconds
# done with pair (idx, jdx) (1, 5) in 0.9931039810180664 seconds
# done with pair (idx, jdx) (1, 6) in 1.348289966583252 seconds
# done with pair (idx, jdx) (1, 7) in 1.7423748970031738 seconds
# done with pair (idx, jdx) (2, 0) in 0.0617060661315918 seconds
# done with pair (idx, jdx) (2, 1) in 0.11263418197631836 seconds
# done with pair (idx, jdx) (2, 2) in 0.23136305809020996 seconds
# done with pair (idx, jdx) (2, 3) in 0.27403879165649414 seconds
# done with pair (idx, jdx) (2, 4) in 1.0796818733215332 seconds
# done with pair (idx, jdx) (2, 5) in 1.7004079818725586 seconds
# done with pair (idx, jdx) (2, 6) in 2.171013832092285 seconds
# done with pair (idx, jdx) (2, 7) in 2.9000399112701416 seconds
# done with pair (idx, jdx) (3, 0) in 0.06941795349121094 seconds
# done with pair (idx, jdx) (3, 1) in 0.1362011432647705 seconds
# done with pair (idx, jdx) (3, 2) in 0.19732403755187988 seconds
# done with pair (idx, jdx) (3, 3) in 0.28000903129577637 seconds
# done with pair (idx, jdx) (3, 4) in 0.7884969711303711 seconds
# done with pair (idx, jdx) (3, 5) in 2.601016044616699 seconds
# done with pair (idx, jdx) (3, 6) in 2.1980719566345215 seconds
# done with pair (idx, jdx) (3, 7) in 2.631270170211792 seconds
# done with pair (idx, jdx) (4, 0) in 0.058287858963012695 seconds
# done with pair (idx, jdx) (4, 1) in 0.1364600658416748 seconds
# done with pair (idx, jdx) (4, 2) in 0.2656271457672119 seconds
# done with pair (idx, jdx) (4, 3) in 0.3698089122772217 seconds
# done with pair (idx, jdx) (4, 4) in 1.0828540325164795 seconds
# done with pair (idx, jdx) (4, 5) in 1.8302488327026367 seconds
# done with pair (idx, jdx) (4, 6) in 2.1908578872680664 seconds
# done with pair (idx, jdx) (4, 7) in 3.3303418159484863 seconds
# done with pair (idx, jdx) (5, 0) in 0.056472063064575195 seconds
# done with pair (idx, jdx) (5, 1) in 0.15821003913879395 seconds
# done with pair (idx, jdx) (5, 2) in 0.3529031276702881 seconds
# done with pair (idx, jdx) (5, 3) in 0.2866339683532715 seconds
# done with pair (idx, jdx) (5, 4) in 1.1875178813934326 seconds
# done with pair (idx, jdx) (5, 5) in 1.502864122390747 seconds
# done with pair (idx, jdx) (5, 6) in 2.2163798809051514 seconds
# done with pair (idx, jdx) (5, 7) in 2.5474607944488525 seconds
# done with pair (idx, jdx) (6, 0) in 0.05440783500671387 seconds
# done with pair (idx, jdx) (6, 1) in 0.19446492195129395 seconds
# done with pair (idx, jdx) (6, 2) in 0.4774448871612549 seconds
# done with pair (idx, jdx) (6, 3) in 0.6292850971221924 seconds
# done with pair (idx, jdx) (6, 4) in 1.1177852153778076 seconds
# done with pair (idx, jdx) (6, 5) in 1.7762770652770996 seconds
# done with pair (idx, jdx) (6, 6) in 2.3852760791778564 seconds
# done with pair (idx, jdx) (6, 7) in 3.283370018005371 seconds
# done with pair (idx, jdx) (7, 0) in 0.06185603141784668 seconds
# done with pair (idx, jdx) (7, 1) in 0.19228029251098633 seconds
# done with pair (idx, jdx) (7, 2) in 0.4405031204223633 seconds
# done with pair (idx, jdx) (7, 3) in 1.137281894683838 seconds
# done with pair (idx, jdx) (7, 4) in 1.2397370338439941 seconds
# done with pair (idx, jdx) (7, 5) in 2.2551581859588623 seconds
# done with pair (idx, jdx) (7, 6) in 2.0112199783325195 seconds
# done with pair (idx, jdx) (7, 7) in 2.7471811771392822 seconds
# done with pair (idx, jdx) (8, 0) in 0.1378021240234375 seconds
# done with pair (idx, jdx) (8, 1) in 0.1096642017364502 seconds
# done with pair (idx, jdx) (8, 2) in 0.2717723846435547 seconds
# done with pair (idx, jdx) (8, 3) in 0.34612512588500977 seconds
# done with pair (idx, jdx) (8, 4) in 1.0467422008514404 seconds
# done with pair (idx, jdx) (8, 5) in 1.5208351612091064 seconds
# done with pair (idx, jdx) (8, 6) in 1.8046331405639648 seconds
# done with pair (idx, jdx) (8, 7) in 2.2125890254974365 seconds
# done with pair (idx, jdx) (9, 0) in 0.10851311683654785 seconds
# done with pair (idx, jdx) (9, 1) in 0.33917999267578125 seconds
# done with pair (idx, jdx) (9, 2) in 0.4317619800567627 seconds
# done with pair (idx, jdx) (9, 3) in 0.644111156463623 seconds
# done with pair (idx, jdx) (9, 4) in 1.0804438591003418 seconds
# done with pair (idx, jdx) (9, 5) in 1.562183141708374 seconds
# done with pair (idx, jdx) (9, 6) in 1.7758350372314453 seconds
# done with pair (idx, jdx) (9, 7) in 2.1800692081451416 seconds
# done with pair (idx, jdx) (10, 0) in 0.06948232650756836 seconds
# done with pair (idx, jdx) (10, 1) in 0.205841064453125 seconds
# done with pair (idx, jdx) (10, 2) in 0.3947761058807373 seconds
# done with pair (idx, jdx) (10, 3) in 0.5312249660491943 seconds
# done with pair (idx, jdx) (10, 4) in 1.0711629390716553 seconds
# done with pair (idx, jdx) (10, 5) in 1.5602149963378906 seconds
# done with pair (idx, jdx) (10, 6) in 2.2202088832855225 seconds
# done with pair (idx, jdx) (10, 7) in 2.2400927543640137 seconds
# done with pair (idx, jdx) (11, 0) in 0.14862418174743652 seconds
# done with pair (idx, jdx) (11, 1) in 0.17036199569702148 seconds
# done with pair (idx, jdx) (11, 2) in 0.1934351921081543 seconds
# done with pair (idx, jdx) (11, 3) in 0.34836697578430176 seconds
# done with pair (idx, jdx) (11, 4) in 0.9170701503753662 seconds
# done with pair (idx, jdx) (11, 5) in 1.3340349197387695 seconds
# done with pair (idx, jdx) (11, 6) in 2.0078771114349365 seconds
# done with pair (idx, jdx) (11, 7) in 2.196753978729248 seconds
# done with pair (idx, jdx) (12, 0) in 0.07092571258544922 seconds
# done with pair (idx, jdx) (12, 1) in 0.09996318817138672 seconds
# done with pair (idx, jdx) (12, 2) in 0.4635961055755615 seconds
# done with pair (idx, jdx) (12, 3) in 0.552793025970459 seconds
# done with pair (idx, jdx) (12, 4) in 0.9283499717712402 seconds
# done with pair (idx, jdx) (12, 5) in 1.5529680252075195 seconds
# done with pair (idx, jdx) (12, 6) in 2.0562191009521484 seconds
# done with pair (idx, jdx) (12, 7) in 2.5538151264190674 seconds
# done with pair (idx, jdx) (13, 0) in 0.0665128231048584 seconds
# done with pair (idx, jdx) (13, 1) in 0.10427689552307129 seconds
# done with pair (idx, jdx) (13, 2) in 0.21147990226745605 seconds
# done with pair (idx, jdx) (13, 3) in 0.2851119041442871 seconds
# done with pair (idx, jdx) (13, 4) in 1.0511107444763184 seconds
# done with pair (idx, jdx) (13, 5) in 1.5590720176696777 seconds
# done with pair (idx, jdx) (13, 6) in 1.4948396682739258 seconds
# done with pair (idx, jdx) (13, 7) in 2.230226993560791 seconds
# done with pair (idx, jdx) (14, 0) in 0.05435490608215332 seconds
# done with pair (idx, jdx) (14, 1) in 0.20539093017578125 seconds
# done with pair (idx, jdx) (14, 2) in 0.41655397415161133 seconds
# done with pair (idx, jdx) (14, 3) in 0.5327649116516113 seconds
# done with pair (idx, jdx) (14, 4) in 1.0698678493499756 seconds
# done with pair (idx, jdx) (14, 5) in 1.618406057357788 seconds
# done with pair (idx, jdx) (14, 6) in 1.817720651626587 seconds
# done with pair (idx, jdx) (14, 7) in 2.1664741039276123 seconds
# done with pair (idx, jdx) (15, 0) in 0.06944584846496582 seconds
# done with pair (idx, jdx) (15, 1) in 0.21445798873901367 seconds
# done with pair (idx, jdx) (15, 2) in 0.4428749084472656 seconds
# done with pair (idx, jdx) (15, 3) in 0.5239331722259521 seconds
# done with pair (idx, jdx) (15, 4) in 0.7788238525390625 seconds
# done with pair (idx, jdx) (15, 5) in 1.5162718296051025 seconds
# done with pair (idx, jdx) (15, 6) in 1.8132860660552979 seconds
# done with pair (idx, jdx) (15, 7) in 2.567383050918579 seconds
# done with pair (idx, jdx) (16, 0) in 0.06035494804382324 seconds
# done with pair (idx, jdx) (16, 1) in 0.1353001594543457 seconds
# done with pair (idx, jdx) (16, 2) in 0.5179383754730225 seconds
# done with pair (idx, jdx) (16, 3) in 0.35563015937805176 seconds
# done with pair (idx, jdx) (16, 4) in 1.0788240432739258 seconds
# done with pair (idx, jdx) (16, 5) in 1.5793049335479736 seconds
# done with pair (idx, jdx) (16, 6) in 1.7345898151397705 seconds
# done with pair (idx, jdx) (16, 7) in 2.2125539779663086 seconds
# done with pair (idx, jdx) (17, 0) in 0.16867685317993164 seconds
# done with pair (idx, jdx) (17, 1) in 0.10425925254821777 seconds
# done with pair (idx, jdx) (17, 2) in 0.2506539821624756 seconds
# done with pair (idx, jdx) (17, 3) in 0.5781512260437012 seconds
# done with pair (idx, jdx) (17, 4) in 0.9025001525878906 seconds
# done with pair (idx, jdx) (17, 5) in 1.3259727954864502 seconds
# done with pair (idx, jdx) (17, 6) in 1.8083269596099854 seconds
# done with pair (idx, jdx) (17, 7) in 2.640531063079834 seconds
# done with pair (idx, jdx) (18, 0) in 0.04375600814819336 seconds
# done with pair (idx, jdx) (18, 1) in 0.31116676330566406 seconds
# done with pair (idx, jdx) (18, 2) in 0.41554999351501465 seconds
# done with pair (idx, jdx) (18, 3) in 0.4742441177368164 seconds
# done with pair (idx, jdx) (18, 4) in 1.0834810733795166 seconds
# done with pair (idx, jdx) (18, 5) in 1.2294788360595703 seconds
# done with pair (idx, jdx) (18, 6) in 1.8000729084014893 seconds
# done with pair (idx, jdx) (18, 7) in 2.837766170501709 seconds
# done with pair (idx, jdx) (19, 0) in 0.05770707130432129 seconds
# done with pair (idx, jdx) (19, 1) in 0.13403797149658203 seconds
# done with pair (idx, jdx) (19, 2) in 0.22156596183776855 seconds
# done with pair (idx, jdx) (19, 3) in 0.28431200981140137 seconds
# done with pair (idx, jdx) (19, 4) in 0.807023286819458 seconds
# done with pair (idx, jdx) (19, 5) in 1.664795160293579 seconds
# done with pair (idx, jdx) (19, 6) in 2.088001012802124 seconds
# done with pair (idx, jdx) (19, 7) in 2.6027119159698486 seconds
# done with pair (idx, jdx) (20, 0) in 0.16903376579284668 seconds
# done with pair (idx, jdx) (20, 1) in 0.2049999237060547 seconds
# done with pair (idx, jdx) (20, 2) in 0.2673351764678955 seconds
# done with pair (idx, jdx) (20, 3) in 0.34773778915405273 seconds
# done with pair (idx, jdx) (20, 4) in 1.1434311866760254 seconds
# done with pair (idx, jdx) (20, 5) in 1.7093029022216797 seconds
# done with pair (idx, jdx) (20, 6) in 2.0272769927978516 seconds
# done with pair (idx, jdx) (20, 7) in 2.338379144668579 seconds
# done with pair (idx, jdx) (21, 0) in 0.05019879341125488 seconds
# done with pair (idx, jdx) (21, 1) in 0.15748310089111328 seconds
# done with pair (idx, jdx) (21, 2) in 0.20517992973327637 seconds
# done with pair (idx, jdx) (21, 3) in 0.27715206146240234 seconds
# done with pair (idx, jdx) (21, 4) in 1.06585693359375 seconds
# done with pair (idx, jdx) (21, 5) in 1.5615730285644531 seconds
# done with pair (idx, jdx) (21, 6) in 2.0927300453186035 seconds
# done with pair (idx, jdx) (21, 7) in 2.5575039386749268 seconds
# done with pair (idx, jdx) (22, 0) in 0.07384920120239258 seconds
# done with pair (idx, jdx) (22, 1) in 0.15438294410705566 seconds
# done with pair (idx, jdx) (22, 2) in 0.42125916481018066 seconds
# done with pair (idx, jdx) (22, 3) in 0.5302169322967529 seconds
# done with pair (idx, jdx) (22, 4) in 1.2759597301483154 seconds
# done with pair (idx, jdx) (22, 5) in 1.5351550579071045 seconds
# done with pair (idx, jdx) (22, 6) in 1.8189690113067627 seconds
# done with pair (idx, jdx) (22, 7) in 2.3111817836761475 seconds
# done with pair (idx, jdx) (23, 0) in 0.09283924102783203 seconds
# done with pair (idx, jdx) (23, 1) in 0.151824951171875 seconds
# done with pair (idx, jdx) (23, 2) in 0.2596118450164795 seconds
# done with pair (idx, jdx) (23, 3) in 0.4152989387512207 seconds
# done with pair (idx, jdx) (23, 4) in 1.133531093597412 seconds
# done with pair (idx, jdx) (23, 5) in 1.645704984664917 seconds
# done with pair (idx, jdx) (23, 6) in 2.0338640213012695 seconds
# done with pair (idx, jdx) (23, 7) in 2.5288381576538086 seconds
# done with pair (idx, jdx) (24, 0) in 0.2746398448944092 seconds
# done with pair (idx, jdx) (24, 1) in 0.31377410888671875 seconds
# done with pair (idx, jdx) (24, 2) in 0.3939018249511719 seconds
# done with pair (idx, jdx) (24, 3) in 0.5136539936065674 seconds
# done with pair (idx, jdx) (24, 4) in 1.072498083114624 seconds
# done with pair (idx, jdx) (24, 5) in 1.8886752128601074 seconds
# done with pair (idx, jdx) (24, 6) in 2.0859150886535645 seconds
# done with pair (idx, jdx) (24, 7) in 2.5780410766601562 seconds
# done with pair (idx, jdx) (25, 0) in 0.07910513877868652 seconds
# done with pair (idx, jdx) (25, 1) in 0.1810460090637207 seconds
# done with pair (idx, jdx) (25, 2) in 0.21124720573425293 seconds
# done with pair (idx, jdx) (25, 3) in 0.26981401443481445 seconds
# done with pair (idx, jdx) (25, 4) in 1.0475733280181885 seconds
# done with pair (idx, jdx) (25, 5) in 1.5378990173339844 seconds
# done with pair (idx, jdx) (25, 6) in 2.1119980812072754 seconds
# done with pair (idx, jdx) (25, 7) in 2.511430263519287 seconds
# done with pair (idx, jdx) (26, 0) in 0.08375000953674316 seconds
# done with pair (idx, jdx) (26, 1) in 0.18959808349609375 seconds
# done with pair (idx, jdx) (26, 2) in 0.28146982192993164 seconds
# done with pair (idx, jdx) (26, 3) in 0.3388700485229492 seconds
# done with pair (idx, jdx) (26, 4) in 1.156836986541748 seconds
# done with pair (idx, jdx) (26, 5) in 1.014955997467041 seconds
# done with pair (idx, jdx) (26, 6) in 2.521630048751831 seconds
# done with pair (idx, jdx) (26, 7) in 2.6121108531951904 seconds
# done with pair (idx, jdx) (27, 0) in 0.09664797782897949 seconds
# done with pair (idx, jdx) (27, 1) in 0.13941287994384766 seconds
# done with pair (idx, jdx) (27, 2) in 0.26972317695617676 seconds
# done with pair (idx, jdx) (27, 3) in 0.2608668804168701 seconds
# done with pair (idx, jdx) (27, 4) in 0.9510908126831055 seconds
# done with pair (idx, jdx) (27, 5) in 1.573307752609253 seconds
# done with pair (idx, jdx) (27, 6) in 2.0522050857543945 seconds
# done with pair (idx, jdx) (27, 7) in 2.629997968673706 seconds
# done with pair (idx, jdx) (28, 0) in 0.07003593444824219 seconds
# done with pair (idx, jdx) (28, 1) in 0.19759678840637207 seconds
# done with pair (idx, jdx) (28, 2) in 0.4784109592437744 seconds
# done with pair (idx, jdx) (28, 3) in 0.561331033706665 seconds
# done with pair (idx, jdx) (28, 4) in 1.277479887008667 seconds
# done with pair (idx, jdx) (28, 5) in 1.6391899585723877 seconds
# done with pair (idx, jdx) (28, 6) in 2.349900960922241 seconds
# done with pair (idx, jdx) (28, 7) in 2.527661085128784 seconds
# done with pair (idx, jdx) (29, 0) in 0.07755112648010254 seconds
# done with pair (idx, jdx) (29, 1) in 0.1416780948638916 seconds
# done with pair (idx, jdx) (29, 2) in 0.3154001235961914 seconds
# done with pair (idx, jdx) (29, 3) in 0.7382299900054932 seconds
# done with pair (idx, jdx) (29, 4) in 1.2213408946990967 seconds
# done with pair (idx, jdx) (29, 5) in 1.4625298976898193 seconds
# done with pair (idx, jdx) (29, 6) in 1.833367109298706 seconds
# done with pair (idx, jdx) (29, 7) in 2.5726470947265625 seconds
# done with pair (idx, jdx) (30, 0) in 0.05782794952392578 seconds
# done with pair (idx, jdx) (30, 1) in 0.1452488899230957 seconds
# done with pair (idx, jdx) (30, 2) in 0.4520149230957031 seconds
# done with pair (idx, jdx) (30, 3) in 0.3436591625213623 seconds
# done with pair (idx, jdx) (30, 4) in 1.0697221755981445 seconds
# done with pair (idx, jdx) (30, 5) in 1.6023070812225342 seconds
# done with pair (idx, jdx) (30, 6) in 2.0644359588623047 seconds
# done with pair (idx, jdx) (30, 7) in 2.4967641830444336 seconds
# done with pair (idx, jdx) (31, 0) in 0.05825304985046387 seconds
# done with pair (idx, jdx) (31, 1) in 0.19170475006103516 seconds
# done with pair (idx, jdx) (31, 2) in 0.3145270347595215 seconds
# done with pair (idx, jdx) (31, 3) in 0.42316484451293945 seconds
# done with pair (idx, jdx) (31, 4) in 0.9038481712341309 seconds
# done with pair (idx, jdx) (31, 5) in 1.6024858951568604 seconds
# done with pair (idx, jdx) (31, 6) in 2.159331798553467 seconds
# done with pair (idx, jdx) (31, 7) in 2.2344510555267334 seconds
# done with pair (idx, jdx) (32, 0) in 0.13990497589111328 seconds
# done with pair (idx, jdx) (32, 1) in 0.2980830669403076 seconds
# done with pair (idx, jdx) (32, 2) in 0.34938597679138184 seconds
# done with pair (idx, jdx) (32, 3) in 0.5382080078125 seconds
# done with pair (idx, jdx) (32, 4) in 1.038193941116333 seconds
# done with pair (idx, jdx) (32, 5) in 1.9205617904663086 seconds
# done with pair (idx, jdx) (32, 6) in 2.1292548179626465 seconds
# done with pair (idx, jdx) (32, 7) in 2.583268165588379 seconds
# done with pair (idx, jdx) (33, 0) in 0.1442270278930664 seconds
# done with pair (idx, jdx) (33, 1) in 0.17511200904846191 seconds
# done with pair (idx, jdx) (33, 2) in 0.2126331329345703 seconds
# done with pair (idx, jdx) (33, 3) in 0.3476848602294922 seconds
# done with pair (idx, jdx) (33, 4) in 0.8510959148406982 seconds
# done with pair (idx, jdx) (33, 5) in 1.2073681354522705 seconds
# done with pair (idx, jdx) (33, 6) in 2.355823040008545 seconds
# done with pair (idx, jdx) (33, 7) in 2.5176799297332764 seconds
# done with pair (idx, jdx) (34, 0) in 0.0855262279510498 seconds
# done with pair (idx, jdx) (34, 1) in 0.16202902793884277 seconds
# done with pair (idx, jdx) (34, 2) in 0.22264909744262695 seconds
# done with pair (idx, jdx) (34, 3) in 0.5266311168670654 seconds
# done with pair (idx, jdx) (34, 4) in 1.058772325515747 seconds
# done with pair (idx, jdx) (34, 5) in 1.8079850673675537 seconds
# done with pair (idx, jdx) (34, 6) in 2.348627805709839 seconds
# done with pair (idx, jdx) (34, 7) in 2.6282241344451904 seconds
# done with pair (idx, jdx) (35, 0) in 0.09377789497375488 seconds
# done with pair (idx, jdx) (35, 1) in 0.14940500259399414 seconds
# done with pair (idx, jdx) (35, 2) in 0.31006789207458496 seconds
# done with pair (idx, jdx) (35, 3) in 0.3352189064025879 seconds
# done with pair (idx, jdx) (35, 4) in 0.8845560550689697 seconds
# done with pair (idx, jdx) (35, 5) in 1.5992710590362549 seconds
# done with pair (idx, jdx) (35, 6) in 2.0489630699157715 seconds
# done with pair (idx, jdx) (35, 7) in 2.4959301948547363 seconds
# done with pair (idx, jdx) (36, 0) in 0.1021571159362793 seconds
# done with pair (idx, jdx) (36, 1) in 0.3077361583709717 seconds
# done with pair (idx, jdx) (36, 2) in 0.46706509590148926 seconds
# done with pair (idx, jdx) (36, 3) in 0.5658040046691895 seconds
# done with pair (idx, jdx) (36, 4) in 0.9359951019287109 seconds
# done with pair (idx, jdx) (36, 5) in 1.4316916465759277 seconds
# done with pair (idx, jdx) (36, 6) in 1.8873319625854492 seconds
# done with pair (idx, jdx) (36, 7) in 2.219533920288086 seconds
# done with pair (idx, jdx) (37, 0) in 0.025006771087646484 seconds
# done with pair (idx, jdx) (37, 1) in 0.16188526153564453 seconds
# done with pair (idx, jdx) (37, 2) in 0.26525282859802246 seconds
# done with pair (idx, jdx) (37, 3) in 0.3499782085418701 seconds
# done with pair (idx, jdx) (37, 4) in 1.1347851753234863 seconds
# done with pair (idx, jdx) (37, 5) in 1.8361191749572754 seconds
# done with pair (idx, jdx) (37, 6) in 2.152583122253418 seconds
# done with pair (idx, jdx) (37, 7) in 2.613327980041504 seconds
# done with pair (idx, jdx) (38, 0) in 0.1577310562133789 seconds
# done with pair (idx, jdx) (38, 1) in 0.3548319339752197 seconds
# done with pair (idx, jdx) (38, 2) in 0.2604343891143799 seconds
# done with pair (idx, jdx) (38, 3) in 0.2719888687133789 seconds
# done with pair (idx, jdx) (38, 4) in 0.6823310852050781 seconds
# done with pair (idx, jdx) (38, 5) in 1.0621650218963623 seconds
# done with pair (idx, jdx) (38, 6) in 1.6098108291625977 seconds
# done with pair (idx, jdx) (38, 7) in 2.9488089084625244 seconds
# done with pair (idx, jdx) (39, 0) in 0.08876490592956543 seconds
# done with pair (idx, jdx) (39, 1) in 0.3338279724121094 seconds
# done with pair (idx, jdx) (39, 2) in 0.2668111324310303 seconds
# done with pair (idx, jdx) (39, 3) in 0.5342237949371338 seconds
# done with pair (idx, jdx) (39, 4) in 1.0579349994659424 seconds
# done with pair (idx, jdx) (39, 5) in 1.591059923171997 seconds
# done with pair (idx, jdx) (39, 6) in 2.2326080799102783 seconds
# done with pair (idx, jdx) (39, 7) in 2.568972110748291 seconds
# done with pair (idx, jdx) (40, 0) in 0.10764908790588379 seconds
# done with pair (idx, jdx) (40, 1) in 0.3040478229522705 seconds
# done with pair (idx, jdx) (40, 2) in 0.2638232707977295 seconds
# done with pair (idx, jdx) (40, 3) in 0.4122281074523926 seconds
# done with pair (idx, jdx) (40, 4) in 1.1141507625579834 seconds
# done with pair (idx, jdx) (40, 5) in 1.60123610496521 seconds
# done with pair (idx, jdx) (40, 6) in 2.033622980117798 seconds
# done with pair (idx, jdx) (40, 7) in 2.508435010910034 seconds
# done with pair (idx, jdx) (41, 0) in 0.0801699161529541 seconds
# done with pair (idx, jdx) (41, 1) in 0.3138158321380615 seconds
# done with pair (idx, jdx) (41, 2) in 0.3456408977508545 seconds
# done with pair (idx, jdx) (41, 3) in 0.6467063426971436 seconds
# done with pair (idx, jdx) (41, 4) in 1.1671669483184814 seconds
# done with pair (idx, jdx) (41, 5) in 1.6672730445861816 seconds
# done with pair (idx, jdx) (41, 6) in 1.85080885887146 seconds
# done with pair (idx, jdx) (41, 7) in 2.2538089752197266 seconds
# done with pair (idx, jdx) (42, 0) in 0.06144523620605469 seconds
# done with pair (idx, jdx) (42, 1) in 0.21260476112365723 seconds
# done with pair (idx, jdx) (42, 2) in 0.3220939636230469 seconds
# done with pair (idx, jdx) (42, 3) in 0.8718008995056152 seconds
# done with pair (idx, jdx) (42, 4) in 1.213040828704834 seconds
# done with pair (idx, jdx) (42, 5) in 1.674501895904541 seconds
# done with pair (idx, jdx) (42, 6) in 2.1082518100738525 seconds
# done with pair (idx, jdx) (42, 7) in 2.907823085784912 seconds
# done with pair (idx, jdx) (43, 0) in 0.08884501457214355 seconds
# done with pair (idx, jdx) (43, 1) in 0.14357614517211914 seconds
# done with pair (idx, jdx) (43, 2) in 0.20432782173156738 seconds
# done with pair (idx, jdx) (43, 3) in 0.34679722785949707 seconds
# done with pair (idx, jdx) (43, 4) in 0.9338891506195068 seconds
# done with pair (idx, jdx) (43, 5) in 1.8496110439300537 seconds
# done with pair (idx, jdx) (43, 6) in 2.3815369606018066 seconds
# done with pair (idx, jdx) (43, 7) in 2.504581928253174 seconds
# done with pair (idx, jdx) (44, 0) in 0.01979804039001465 seconds
# done with pair (idx, jdx) (44, 1) in 0.174025297164917 seconds
# done with pair (idx, jdx) (44, 2) in 0.20473599433898926 seconds
# done with pair (idx, jdx) (44, 3) in 0.27663707733154297 seconds
# done with pair (idx, jdx) (44, 4) in 1.0698580741882324 seconds
# done with pair (idx, jdx) (44, 5) in 1.8102121353149414 seconds
# done with pair (idx, jdx) (44, 6) in 2.154700994491577 seconds
# done with pair (idx, jdx) (44, 7) in 2.597573757171631 seconds
# done with pair (idx, jdx) (45, 0) in 0.1425929069519043 seconds
# done with pair (idx, jdx) (45, 1) in 0.28152990341186523 seconds
# done with pair (idx, jdx) (45, 2) in 0.4227719306945801 seconds
# done with pair (idx, jdx) (45, 3) in 0.5414950847625732 seconds
# done with pair (idx, jdx) (45, 4) in 1.0613000392913818 seconds
# done with pair (idx, jdx) (45, 5) in 1.8163998126983643 seconds
# done with pair (idx, jdx) (45, 6) in 2.323514938354492 seconds
# done with pair (idx, jdx) (45, 7) in 2.5986931324005127 seconds
# done with pair (idx, jdx) (46, 0) in 0.06638193130493164 seconds
# done with pair (idx, jdx) (46, 1) in 0.3122091293334961 seconds
# done with pair (idx, jdx) (46, 2) in 0.41224098205566406 seconds
# done with pair (idx, jdx) (46, 3) in 0.5499148368835449 seconds
# done with pair (idx, jdx) (46, 4) in 0.9456489086151123 seconds
# done with pair (idx, jdx) (46, 5) in 1.6152009963989258 seconds
# done with pair (idx, jdx) (46, 6) in 2.561605930328369 seconds
# done with pair (idx, jdx) (46, 7) in 2.614536762237549 seconds
# done with pair (idx, jdx) (47, 0) in 0.041043996810913086 seconds
# done with pair (idx, jdx) (47, 1) in 0.11229896545410156 seconds
# done with pair (idx, jdx) (47, 2) in 0.2113652229309082 seconds
# done with pair (idx, jdx) (47, 3) in 0.5436890125274658 seconds
# done with pair (idx, jdx) (47, 4) in 1.0497500896453857 seconds
# done with pair (idx, jdx) (47, 5) in 1.817612886428833 seconds
# done with pair (idx, jdx) (47, 6) in 2.3315463066101074 seconds
# done with pair (idx, jdx) (47, 7) in 2.9055850505828857 seconds
# done with pair (idx, jdx) (48, 0) in 0.07480883598327637 seconds
# done with pair (idx, jdx) (48, 1) in 0.22491192817687988 seconds
# done with pair (idx, jdx) (48, 2) in 0.27971363067626953 seconds
# done with pair (idx, jdx) (48, 3) in 0.3761889934539795 seconds
# done with pair (idx, jdx) (48, 4) in 1.213641881942749 seconds
# done with pair (idx, jdx) (48, 5) in 1.6348769664764404 seconds
# done with pair (idx, jdx) (48, 6) in 1.8130712509155273 seconds
# done with pair (idx, jdx) (48, 7) in 2.261863946914673 seconds
# done with pair (idx, jdx) (49, 0) in 0.15156078338623047 seconds
# done with pair (idx, jdx) (49, 1) in 0.17154288291931152 seconds
# done with pair (idx, jdx) (49, 2) in 0.3892519474029541 seconds
# done with pair (idx, jdx) (49, 3) in 0.5130088329315186 seconds
# done with pair (idx, jdx) (49, 4) in 1.0803098678588867 seconds
# done with pair (idx, jdx) (49, 5) in 1.6824710369110107 seconds
# done with pair (idx, jdx) (49, 6) in 2.138415813446045 seconds
# done with pair (idx, jdx) (49, 7) in 2.551625967025757 seconds
# done with pair (idx, jdx) (50, 0) in 0.05859684944152832 seconds
# done with pair (idx, jdx) (50, 1) in 0.14176201820373535 seconds
# done with pair (idx, jdx) (50, 2) in 0.5210549831390381 seconds
# done with pair (idx, jdx) (50, 3) in 0.6113667488098145 seconds
# done with pair (idx, jdx) (50, 4) in 1.0581550598144531 seconds
# done with pair (idx, jdx) (50, 5) in 1.5825879573822021 seconds
# done with pair (idx, jdx) (50, 6) in 2.1063427925109863 seconds
# done with pair (idx, jdx) (50, 7) in 2.583045244216919 seconds
# done with pair (idx, jdx) (51, 0) in 0.07506084442138672 seconds
# done with pair (idx, jdx) (51, 1) in 0.1452622413635254 seconds
# done with pair (idx, jdx) (51, 2) in 0.24762177467346191 seconds
# done with pair (idx, jdx) (51, 3) in 0.39916396141052246 seconds
# done with pair (idx, jdx) (51, 4) in 1.2041232585906982 seconds
# done with pair (idx, jdx) (51, 5) in 1.9194908142089844 seconds
# done with pair (idx, jdx) (51, 6) in 2.1323370933532715 seconds
# done with pair (idx, jdx) (51, 7) in 2.2299559116363525 seconds
# done with pair (idx, jdx) (52, 0) in 0.07703876495361328 seconds
# done with pair (idx, jdx) (52, 1) in 0.13844037055969238 seconds
# done with pair (idx, jdx) (52, 2) in 0.5562870502471924 seconds
# done with pair (idx, jdx) (52, 3) in 0.5268239974975586 seconds
# done with pair (idx, jdx) (52, 4) in 1.1678738594055176 seconds
# done with pair (idx, jdx) (52, 5) in 1.7505521774291992 seconds
# done with pair (idx, jdx) (52, 6) in 2.1876959800720215 seconds
# done with pair (idx, jdx) (52, 7) in 2.6666910648345947 seconds
# done with pair (idx, jdx) (53, 0) in 0.16643905639648438 seconds
# done with pair (idx, jdx) (53, 1) in 0.1462860107421875 seconds
# done with pair (idx, jdx) (53, 2) in 0.20946407318115234 seconds
# done with pair (idx, jdx) (53, 3) in 0.2765200138092041 seconds
# done with pair (idx, jdx) (53, 4) in 0.8176651000976562 seconds
# done with pair (idx, jdx) (53, 5) in 1.5816709995269775 seconds
# done with pair (idx, jdx) (53, 6) in 1.811636209487915 seconds
# done with pair (idx, jdx) (53, 7) in 2.236180067062378 seconds
# done with pair (idx, jdx) (54, 0) in 0.07106804847717285 seconds
# done with pair (idx, jdx) (54, 1) in 0.2678511142730713 seconds
# done with pair (idx, jdx) (54, 2) in 0.3928959369659424 seconds
# done with pair (idx, jdx) (54, 3) in 0.34006714820861816 seconds
# done with pair (idx, jdx) (54, 4) in 1.0282292366027832 seconds
# done with pair (idx, jdx) (54, 5) in 1.6519427299499512 seconds
# done with pair (idx, jdx) (54, 6) in 2.0974669456481934 seconds
# done with pair (idx, jdx) (54, 7) in 2.674462080001831 seconds
# done with pair (idx, jdx) (55, 0) in 0.07277202606201172 seconds
# done with pair (idx, jdx) (55, 1) in 0.1579127311706543 seconds
# done with pair (idx, jdx) (55, 2) in 0.5121431350708008 seconds
# done with pair (idx, jdx) (55, 3) in 0.6274969577789307 seconds
# done with pair (idx, jdx) (55, 4) in 1.1264259815216064 seconds
# done with pair (idx, jdx) (55, 5) in 1.6023290157318115 seconds
# done with pair (idx, jdx) (55, 6) in 2.0612428188323975 seconds
# done with pair (idx, jdx) (55, 7) in 2.216938018798828 seconds
# done with pair (idx, jdx) (56, 0) in 0.08431482315063477 seconds
# done with pair (idx, jdx) (56, 1) in 0.27854299545288086 seconds
# done with pair (idx, jdx) (56, 2) in 0.19854283332824707 seconds
# done with pair (idx, jdx) (56, 3) in 0.27359533309936523 seconds
# done with pair (idx, jdx) (56, 4) in 0.6951601505279541 seconds
# done with pair (idx, jdx) (56, 5) in 1.924056053161621 seconds
# done with pair (idx, jdx) (56, 6) in 2.360517978668213 seconds
# done with pair (idx, jdx) (56, 7) in 2.5676491260528564 seconds
# done with pair (idx, jdx) (57, 0) in 0.16358494758605957 seconds
# done with pair (idx, jdx) (57, 1) in 0.2084958553314209 seconds
# done with pair (idx, jdx) (57, 2) in 0.2681710720062256 seconds
# done with pair (idx, jdx) (57, 3) in 0.2746868133544922 seconds
# done with pair (idx, jdx) (57, 4) in 0.678947925567627 seconds
# done with pair (idx, jdx) (57, 5) in 1.5462608337402344 seconds
# done with pair (idx, jdx) (57, 6) in 2.113595962524414 seconds
# done with pair (idx, jdx) (57, 7) in 2.606029987335205 seconds
# done with pair (idx, jdx) (58, 0) in 0.04245877265930176 seconds
# done with pair (idx, jdx) (58, 1) in 0.13853096961975098 seconds
# done with pair (idx, jdx) (58, 2) in 0.4221019744873047 seconds
# done with pair (idx, jdx) (58, 3) in 0.4917261600494385 seconds
# done with pair (idx, jdx) (58, 4) in 1.115990161895752 seconds
# done with pair (idx, jdx) (58, 5) in 1.6597330570220947 seconds
# done with pair (idx, jdx) (58, 6) in 1.8497989177703857 seconds
# done with pair (idx, jdx) (58, 7) in 2.2424581050872803 seconds
# done with pair (idx, jdx) (59, 0) in 0.04074597358703613 seconds
# done with pair (idx, jdx) (59, 1) in 0.11194705963134766 seconds
# done with pair (idx, jdx) (59, 2) in 0.40819883346557617 seconds
# done with pair (idx, jdx) (59, 3) in 0.5392258167266846 seconds
# done with pair (idx, jdx) (59, 4) in 1.045576810836792 seconds
# done with pair (idx, jdx) (59, 5) in 1.4594180583953857 seconds
# done with pair (idx, jdx) (59, 6) in 1.848262071609497 seconds
# done with pair (idx, jdx) (59, 7) in 2.306486129760742 seconds
# done with pair (idx, jdx) (60, 0) in 0.14277410507202148 seconds
# done with pair (idx, jdx) (60, 1) in 0.1399979591369629 seconds
# done with pair (idx, jdx) (60, 2) in 0.3142991065979004 seconds
# done with pair (idx, jdx) (60, 3) in 0.5706360340118408 seconds
# done with pair (idx, jdx) (60, 4) in 1.1147420406341553 seconds
# done with pair (idx, jdx) (60, 5) in 1.609544038772583 seconds
# done with pair (idx, jdx) (60, 6) in 2.0652291774749756 seconds
# done with pair (idx, jdx) (60, 7) in 2.5569846630096436 seconds
# done with pair (idx, jdx) (61, 0) in 0.13916492462158203 seconds
# done with pair (idx, jdx) (61, 1) in 0.4739370346069336 seconds
# done with pair (idx, jdx) (61, 2) in 0.2766568660736084 seconds
# done with pair (idx, jdx) (61, 3) in 0.47206926345825195 seconds
# done with pair (idx, jdx) (61, 4) in 1.1269299983978271 seconds
# done with pair (idx, jdx) (61, 5) in 1.6540679931640625 seconds
# done with pair (idx, jdx) (61, 6) in 2.1409358978271484 seconds
# done with pair (idx, jdx) (61, 7) in 2.208191156387329 seconds
# done with pair (idx, jdx) (62, 0) in 0.057917118072509766 seconds
# done with pair (idx, jdx) (62, 1) in 0.1336231231689453 seconds
# done with pair (idx, jdx) (62, 2) in 0.2592959403991699 seconds
# done with pair (idx, jdx) (62, 3) in 0.3263537883758545 seconds
# done with pair (idx, jdx) (62, 4) in 1.0437381267547607 seconds
# done with pair (idx, jdx) (62, 5) in 1.5837628841400146 seconds
# done with pair (idx, jdx) (62, 6) in 2.0285067558288574 seconds
# done with pair (idx, jdx) (62, 7) in 2.642881155014038 seconds
# done with pair (idx, jdx) (63, 0) in 0.1001582145690918 seconds
# done with pair (idx, jdx) (63, 1) in 0.19937682151794434 seconds
# done with pair (idx, jdx) (63, 2) in 0.4261960983276367 seconds
# done with pair (idx, jdx) (63, 3) in 0.5562479496002197 seconds
# done with pair (idx, jdx) (63, 4) in 1.1207637786865234 seconds
# done with pair (idx, jdx) (63, 5) in 1.4139411449432373 seconds
# done with pair (idx, jdx) (63, 6) in 1.8610858917236328 seconds
# done with pair (idx, jdx) (63, 7) in 2.2451980113983154 seconds
# done with pair (idx, jdx) (64, 0) in 0.051688194274902344 seconds
# done with pair (idx, jdx) (64, 1) in 0.13334894180297852 seconds
# done with pair (idx, jdx) (64, 2) in 0.21251201629638672 seconds
# done with pair (idx, jdx) (64, 3) in 0.343533992767334 seconds
# done with pair (idx, jdx) (64, 4) in 1.0256240367889404 seconds
# done with pair (idx, jdx) (64, 5) in 1.6200149059295654 seconds
# done with pair (idx, jdx) (64, 6) in 1.9096901416778564 seconds
# done with pair (idx, jdx) (64, 7) in 2.286055088043213 seconds
# done with pair (idx, jdx) (65, 0) in 0.09453821182250977 seconds
# done with pair (idx, jdx) (65, 1) in 0.6340720653533936 seconds
# done with pair (idx, jdx) (65, 2) in 0.2675449848175049 seconds
# done with pair (idx, jdx) (65, 3) in 0.7628672122955322 seconds
# done with pair (idx, jdx) (65, 4) in 1.0749807357788086 seconds
# done with pair (idx, jdx) (65, 5) in 1.6015350818634033 seconds
# done with pair (idx, jdx) (65, 6) in 2.0545520782470703 seconds
# done with pair (idx, jdx) (65, 7) in 2.4872488975524902 seconds
# done with pair (idx, jdx) (66, 0) in 0.13820195198059082 seconds
# done with pair (idx, jdx) (66, 1) in 0.3695051670074463 seconds
# done with pair (idx, jdx) (66, 2) in 0.3785374164581299 seconds
# done with pair (idx, jdx) (66, 3) in 0.3369262218475342 seconds
# done with pair (idx, jdx) (66, 4) in 0.534221887588501 seconds
# done with pair (idx, jdx) (66, 5) in 1.7209627628326416 seconds
# done with pair (idx, jdx) (66, 6) in 2.0961809158325195 seconds
# done with pair (idx, jdx) (66, 7) in 2.608074903488159 seconds
# done with pair (idx, jdx) (67, 0) in 0.059491872787475586 seconds
# done with pair (idx, jdx) (67, 1) in 0.5856070518493652 seconds
# done with pair (idx, jdx) (67, 2) in 0.43187618255615234 seconds
# done with pair (idx, jdx) (67, 3) in 0.5570650100708008 seconds
# done with pair (idx, jdx) (67, 4) in 1.1120741367340088 seconds
# done with pair (idx, jdx) (67, 5) in 1.6332380771636963 seconds
# done with pair (idx, jdx) (67, 6) in 2.0519587993621826 seconds
# done with pair (idx, jdx) (67, 7) in 2.249315023422241 seconds
# done with pair (idx, jdx) (68, 0) in 0.18311691284179688 seconds
# done with pair (idx, jdx) (68, 1) in 0.10492277145385742 seconds
# done with pair (idx, jdx) (68, 2) in 0.22477293014526367 seconds
# done with pair (idx, jdx) (68, 3) in 0.4277923107147217 seconds
# done with pair (idx, jdx) (68, 4) in 1.0732388496398926 seconds
# done with pair (idx, jdx) (68, 5) in 1.6124417781829834 seconds
# done with pair (idx, jdx) (68, 6) in 2.092625856399536 seconds
# done with pair (idx, jdx) (68, 7) in 2.228860378265381 seconds
# done with pair (idx, jdx) (69, 0) in 0.24195265769958496 seconds
# done with pair (idx, jdx) (69, 1) in 0.17568016052246094 seconds
# done with pair (idx, jdx) (69, 2) in 0.2583458423614502 seconds
# done with pair (idx, jdx) (69, 3) in 0.5257470607757568 seconds
# done with pair (idx, jdx) (69, 4) in 1.0146849155426025 seconds
# done with pair (idx, jdx) (69, 5) in 1.5672011375427246 seconds
# done with pair (idx, jdx) (69, 6) in 2.1111061573028564 seconds
# done with pair (idx, jdx) (69, 7) in 2.5639190673828125 seconds
# done with pair (idx, jdx) (70, 0) in 0.058129072189331055 seconds
# done with pair (idx, jdx) (70, 1) in 0.22310090065002441 seconds
# done with pair (idx, jdx) (70, 2) in 0.5111978054046631 seconds
# done with pair (idx, jdx) (70, 3) in 0.5404911041259766 seconds
# done with pair (idx, jdx) (70, 4) in 0.9717850685119629 seconds
# done with pair (idx, jdx) (70, 5) in 1.4078819751739502 seconds
# done with pair (idx, jdx) (70, 6) in 1.8261628150939941 seconds
# done with pair (idx, jdx) (70, 7) in 2.2113261222839355 seconds
# done with pair (idx, jdx) (71, 0) in 0.07644200325012207 seconds
# done with pair (idx, jdx) (71, 1) in 0.11309981346130371 seconds
# done with pair (idx, jdx) (71, 2) in 0.257720947265625 seconds
# done with pair (idx, jdx) (71, 3) in 0.36400699615478516 seconds
# done with pair (idx, jdx) (71, 4) in 1.0767128467559814 seconds
# done with pair (idx, jdx) (71, 5) in 1.6420841217041016 seconds
# done with pair (idx, jdx) (71, 6) in 2.0764200687408447 seconds
# done with pair (idx, jdx) (71, 7) in 2.614269733428955 seconds
# done with pair (idx, jdx) (72, 0) in 0.06024312973022461 seconds
# done with pair (idx, jdx) (72, 1) in 0.280256986618042 seconds
# done with pair (idx, jdx) (72, 2) in 0.461637020111084 seconds
# done with pair (idx, jdx) (72, 3) in 0.5372307300567627 seconds
# done with pair (idx, jdx) (72, 4) in 1.6694848537445068 seconds
# done with pair (idx, jdx) (72, 5) in 1.966738224029541 seconds
# done with pair (idx, jdx) (72, 6) in 2.0536251068115234 seconds
# done with pair (idx, jdx) (72, 7) in 2.5748720169067383 seconds
# done with pair (idx, jdx) (73, 0) in 0.16756105422973633 seconds
# done with pair (idx, jdx) (73, 1) in 0.292316198348999 seconds
# done with pair (idx, jdx) (73, 2) in 0.37134480476379395 seconds
# done with pair (idx, jdx) (73, 3) in 0.47930312156677246 seconds
# done with pair (idx, jdx) (73, 4) in 1.1153008937835693 seconds
# done with pair (idx, jdx) (73, 5) in 2.055400848388672 seconds
# done with pair (idx, jdx) (73, 6) in 2.359038829803467 seconds
# done with pair (idx, jdx) (73, 7) in 2.2569172382354736 seconds
# done with pair (idx, jdx) (74, 0) in 0.05494403839111328 seconds
# done with pair (idx, jdx) (74, 1) in 0.26326513290405273 seconds
# done with pair (idx, jdx) (74, 2) in 0.39635205268859863 seconds
# done with pair (idx, jdx) (74, 3) in 0.5338230133056641 seconds
# done with pair (idx, jdx) (74, 4) in 0.9282031059265137 seconds
# done with pair (idx, jdx) (74, 5) in 1.6199688911437988 seconds
# done with pair (idx, jdx) (74, 6) in 2.1373202800750732 seconds
# done with pair (idx, jdx) (74, 7) in 2.578425168991089 seconds
# done with pair (idx, jdx) (75, 0) in 0.07817196846008301 seconds
# done with pair (idx, jdx) (75, 1) in 0.1391770839691162 seconds
# done with pair (idx, jdx) (75, 2) in 0.22963809967041016 seconds
# done with pair (idx, jdx) (75, 3) in 0.6599130630493164 seconds
# done with pair (idx, jdx) (75, 4) in 1.1487627029418945 seconds
# done with pair (idx, jdx) (75, 5) in 2.3250510692596436 seconds
# done with pair (idx, jdx) (75, 6) in 2.4394209384918213 seconds
# done with pair (idx, jdx) (75, 7) in 2.537285327911377 seconds
# done with pair (idx, jdx) (76, 0) in 0.0636899471282959 seconds
# done with pair (idx, jdx) (76, 1) in 0.1375739574432373 seconds
# done with pair (idx, jdx) (76, 2) in 0.5213689804077148 seconds
# done with pair (idx, jdx) (76, 3) in 0.587399959564209 seconds
# done with pair (idx, jdx) (76, 4) in 1.0785727500915527 seconds
# done with pair (idx, jdx) (76, 5) in 1.7463772296905518 seconds
# done with pair (idx, jdx) (76, 6) in 2.201683759689331 seconds
# done with pair (idx, jdx) (76, 7) in 2.6101508140563965 seconds
# done with pair (idx, jdx) (77, 0) in 0.08997011184692383 seconds
# done with pair (idx, jdx) (77, 1) in 0.20747804641723633 seconds
# done with pair (idx, jdx) (77, 2) in 0.5070106983184814 seconds
# done with pair (idx, jdx) (77, 3) in 1.1561589241027832 seconds
# done with pair (idx, jdx) (77, 4) in 1.3756842613220215 seconds
# done with pair (idx, jdx) (77, 5) in 1.4238929748535156 seconds
# done with pair (idx, jdx) (77, 6) in 1.9108731746673584 seconds
# done with pair (idx, jdx) (77, 7) in 2.272193193435669 seconds
# done with pair (idx, jdx) (78, 0) in 0.07362890243530273 seconds
# done with pair (idx, jdx) (78, 1) in 0.3143908977508545 seconds
# done with pair (idx, jdx) (78, 2) in 0.4138760566711426 seconds
# done with pair (idx, jdx) (78, 3) in 0.5843679904937744 seconds
# done with pair (idx, jdx) (78, 4) in 1.125143051147461 seconds
# done with pair (idx, jdx) (78, 5) in 1.6608209609985352 seconds
# done with pair (idx, jdx) (78, 6) in 2.0547759532928467 seconds
# done with pair (idx, jdx) (78, 7) in 2.5713112354278564 seconds
# done with pair (idx, jdx) (79, 0) in 0.08407878875732422 seconds
# done with pair (idx, jdx) (79, 1) in 0.3437368869781494 seconds
# done with pair (idx, jdx) (79, 2) in 0.28933215141296387 seconds
# done with pair (idx, jdx) (79, 3) in 0.5704760551452637 seconds
# done with pair (idx, jdx) (79, 4) in 1.1549689769744873 seconds
# done with pair (idx, jdx) (79, 5) in 1.4975581169128418 seconds
# done with pair (idx, jdx) (79, 6) in 1.8948750495910645 seconds
# done with pair (idx, jdx) (79, 7) in 2.268587112426758 seconds
# done with pair (idx, jdx) (80, 0) in 0.07090210914611816 seconds
# done with pair (idx, jdx) (80, 1) in 0.23955297470092773 seconds
# done with pair (idx, jdx) (80, 2) in 0.47800397872924805 seconds
# done with pair (idx, jdx) (80, 3) in 0.5702097415924072 seconds
# done with pair (idx, jdx) (80, 4) in 0.9153618812561035 seconds
# done with pair (idx, jdx) (80, 5) in 1.1853971481323242 seconds
# done with pair (idx, jdx) (80, 6) in 2.0374832153320312 seconds
# done with pair (idx, jdx) (80, 7) in 2.525002956390381 seconds
# done with pair (idx, jdx) (81, 0) in 0.09316086769104004 seconds
# done with pair (idx, jdx) (81, 1) in 0.3373749256134033 seconds
# done with pair (idx, jdx) (81, 2) in 0.43072009086608887 seconds
# done with pair (idx, jdx) (81, 3) in 0.546299934387207 seconds
# done with pair (idx, jdx) (81, 4) in 0.9654641151428223 seconds
# done with pair (idx, jdx) (81, 5) in 1.7057530879974365 seconds
# done with pair (idx, jdx) (81, 6) in 2.0887861251831055 seconds
# done with pair (idx, jdx) (81, 7) in 2.5578341484069824 seconds
# done with pair (idx, jdx) (82, 0) in 0.0719139575958252 seconds
# done with pair (idx, jdx) (82, 1) in 0.15390610694885254 seconds
# done with pair (idx, jdx) (82, 2) in 0.27083325386047363 seconds
# done with pair (idx, jdx) (82, 3) in 0.364285945892334 seconds
# done with pair (idx, jdx) (82, 4) in 1.0946202278137207 seconds
# done with pair (idx, jdx) (82, 5) in 1.6040630340576172 seconds
# done with pair (idx, jdx) (82, 6) in 2.1124417781829834 seconds
# done with pair (idx, jdx) (82, 7) in 2.5904858112335205 seconds
# done with pair (idx, jdx) (83, 0) in 0.10313296318054199 seconds
# done with pair (idx, jdx) (83, 1) in 0.1435708999633789 seconds
# done with pair (idx, jdx) (83, 2) in 0.22685599327087402 seconds
# done with pair (idx, jdx) (83, 3) in 0.2666349411010742 seconds
# done with pair (idx, jdx) (83, 4) in 0.9157650470733643 seconds
# done with pair (idx, jdx) (83, 5) in 1.6160869598388672 seconds
# done with pair (idx, jdx) (83, 6) in 1.8469979763031006 seconds
# done with pair (idx, jdx) (83, 7) in 2.245990753173828 seconds
# done with pair (idx, jdx) (84, 0) in 0.12106609344482422 seconds
# done with pair (idx, jdx) (84, 1) in 0.2752528190612793 seconds
# done with pair (idx, jdx) (84, 2) in 0.41562318801879883 seconds
# done with pair (idx, jdx) (84, 3) in 0.5361900329589844 seconds
# done with pair (idx, jdx) (84, 4) in 1.0540149211883545 seconds
# done with pair (idx, jdx) (84, 5) in 1.6884527206420898 seconds
# done with pair (idx, jdx) (84, 6) in 2.098804235458374 seconds
# done with pair (idx, jdx) (84, 7) in 2.674381971359253 seconds
# done with pair (idx, jdx) (85, 0) in 0.09206223487854004 seconds
# done with pair (idx, jdx) (85, 1) in 0.10709476470947266 seconds
# done with pair (idx, jdx) (85, 2) in 0.21404218673706055 seconds
# done with pair (idx, jdx) (85, 3) in 0.30162596702575684 seconds
# done with pair (idx, jdx) (85, 4) in 1.076854944229126 seconds
# done with pair (idx, jdx) (85, 5) in 1.773224115371704 seconds
# done with pair (idx, jdx) (85, 6) in 2.3494677543640137 seconds
# done with pair (idx, jdx) (85, 7) in 2.5292811393737793 seconds
# done with pair (idx, jdx) (86, 0) in 0.07559323310852051 seconds
# done with pair (idx, jdx) (86, 1) in 0.13229584693908691 seconds
# done with pair (idx, jdx) (86, 2) in 0.4021890163421631 seconds
# done with pair (idx, jdx) (86, 3) in 0.6167707443237305 seconds
# done with pair (idx, jdx) (86, 4) in 1.0732438564300537 seconds
# done with pair (idx, jdx) (86, 5) in 1.2337322235107422 seconds
# done with pair (idx, jdx) (86, 6) in 2.3897838592529297 seconds
# done with pair (idx, jdx) (86, 7) in 2.5023679733276367 seconds
# done with pair (idx, jdx) (87, 0) in 0.07253885269165039 seconds
# done with pair (idx, jdx) (87, 1) in 0.279771089553833 seconds
# done with pair (idx, jdx) (87, 2) in 0.4497208595275879 seconds
# done with pair (idx, jdx) (87, 3) in 0.5175178050994873 seconds
# done with pair (idx, jdx) (87, 4) in 0.9110589027404785 seconds
# done with pair (idx, jdx) (87, 5) in 1.615868091583252 seconds
# done with pair (idx, jdx) (87, 6) in 2.081125020980835 seconds
# done with pair (idx, jdx) (87, 7) in 2.590999126434326 seconds
# done with pair (idx, jdx) (88, 0) in 0.1517350673675537 seconds
# done with pair (idx, jdx) (88, 1) in 0.18660783767700195 seconds
# done with pair (idx, jdx) (88, 2) in 0.25957298278808594 seconds
# done with pair (idx, jdx) (88, 3) in 0.4145212173461914 seconds
# done with pair (idx, jdx) (88, 4) in 1.0702738761901855 seconds
# done with pair (idx, jdx) (88, 5) in 1.6267421245574951 seconds
# done with pair (idx, jdx) (88, 6) in 2.103192090988159 seconds
# done with pair (idx, jdx) (88, 7) in 2.192164897918701 seconds
# done with pair (idx, jdx) (89, 0) in 0.07090902328491211 seconds
# done with pair (idx, jdx) (89, 1) in 0.1385788917541504 seconds
# done with pair (idx, jdx) (89, 2) in 0.21251201629638672 seconds
# done with pair (idx, jdx) (89, 3) in 0.5272550582885742 seconds
# done with pair (idx, jdx) (89, 4) in 1.0334956645965576 seconds
# done with pair (idx, jdx) (89, 5) in 1.7218828201293945 seconds
# done with pair (idx, jdx) (89, 6) in 2.546665906906128 seconds
# done with pair (idx, jdx) (89, 7) in 2.2945001125335693 seconds
# done with pair (idx, jdx) (90, 0) in 0.09984469413757324 seconds
# done with pair (idx, jdx) (90, 1) in 0.24173593521118164 seconds
# done with pair (idx, jdx) (90, 2) in 0.3432760238647461 seconds
# done with pair (idx, jdx) (90, 3) in 0.5467681884765625 seconds
# done with pair (idx, jdx) (90, 4) in 1.0397801399230957 seconds
# done with pair (idx, jdx) (90, 5) in 1.5773003101348877 seconds
# done with pair (idx, jdx) (90, 6) in 2.0739221572875977 seconds
# done with pair (idx, jdx) (90, 7) in 2.2601969242095947 seconds
# done with pair (idx, jdx) (91, 0) in 0.15119385719299316 seconds
# done with pair (idx, jdx) (91, 1) in 0.26309919357299805 seconds
# done with pair (idx, jdx) (91, 2) in 0.4138610363006592 seconds
# done with pair (idx, jdx) (91, 3) in 0.5463120937347412 seconds
# done with pair (idx, jdx) (91, 4) in 1.0794439315795898 seconds
# done with pair (idx, jdx) (91, 5) in 1.6667582988739014 seconds
# done with pair (idx, jdx) (91, 6) in 2.1301398277282715 seconds
# done with pair (idx, jdx) (91, 7) in 2.2767510414123535 seconds
# done with pair (idx, jdx) (92, 0) in 0.04117083549499512 seconds
# done with pair (idx, jdx) (92, 1) in 0.13661503791809082 seconds
# done with pair (idx, jdx) (92, 2) in 0.2461681365966797 seconds
# done with pair (idx, jdx) (92, 3) in 0.39418697357177734 seconds
# done with pair (idx, jdx) (92, 4) in 0.7146687507629395 seconds
# done with pair (idx, jdx) (92, 5) in 1.583456039428711 seconds
# done with pair (idx, jdx) (92, 6) in 2.1000890731811523 seconds
# done with pair (idx, jdx) (92, 7) in 2.592609167098999 seconds
# done with pair (idx, jdx) (93, 0) in 0.026439905166625977 seconds
# done with pair (idx, jdx) (93, 1) in 0.24482274055480957 seconds
# done with pair (idx, jdx) (93, 2) in 0.3146018981933594 seconds
# done with pair (idx, jdx) (93, 3) in 0.5806479454040527 seconds
# done with pair (idx, jdx) (93, 4) in 1.1732287406921387 seconds
# done with pair (idx, jdx) (93, 5) in 1.6247971057891846 seconds
# done with pair (idx, jdx) (93, 6) in 2.052436113357544 seconds
# done with pair (idx, jdx) (93, 7) in 2.540684938430786 seconds
# done with pair (idx, jdx) (94, 0) in 0.024807214736938477 seconds
# done with pair (idx, jdx) (94, 1) in 0.1358492374420166 seconds
# done with pair (idx, jdx) (94, 2) in 0.38047289848327637 seconds
# done with pair (idx, jdx) (94, 3) in 0.5314340591430664 seconds
# done with pair (idx, jdx) (94, 4) in 0.9070298671722412 seconds
# done with pair (idx, jdx) (94, 5) in 1.4321329593658447 seconds
# done with pair (idx, jdx) (94, 6) in 2.180504083633423 seconds
# done with pair (idx, jdx) (94, 7) in 2.549643039703369 seconds
# done with pair (idx, jdx) (95, 0) in 0.08394312858581543 seconds
# done with pair (idx, jdx) (95, 1) in 0.18291020393371582 seconds
# done with pair (idx, jdx) (95, 2) in 0.27976512908935547 seconds
# done with pair (idx, jdx) (95, 3) in 0.3522822856903076 seconds
# done with pair (idx, jdx) (95, 4) in 0.665198802947998 seconds
# done with pair (idx, jdx) (95, 5) in 1.6078598499298096 seconds
# done with pair (idx, jdx) (95, 6) in 2.079455852508545 seconds
# done with pair (idx, jdx) (95, 7) in 2.550734758377075 seconds
# done with pair (idx, jdx) (96, 0) in 0.14009690284729004 seconds
# done with pair (idx, jdx) (96, 1) in 0.17531299591064453 seconds
# done with pair (idx, jdx) (96, 2) in 0.4064030647277832 seconds
# done with pair (idx, jdx) (96, 3) in 0.5749359130859375 seconds
# done with pair (idx, jdx) (96, 4) in 1.0750458240509033 seconds
# done with pair (idx, jdx) (96, 5) in 1.6311500072479248 seconds
# done with pair (idx, jdx) (96, 6) in 2.172438859939575 seconds
# done with pair (idx, jdx) (96, 7) in 2.5694808959960938 seconds
# done with pair (idx, jdx) (97, 0) in 0.05854511260986328 seconds
# done with pair (idx, jdx) (97, 1) in 0.2944800853729248 seconds
# done with pair (idx, jdx) (97, 2) in 0.5824460983276367 seconds
# done with pair (idx, jdx) (97, 3) in 0.5814371109008789 seconds
# done with pair (idx, jdx) (97, 4) in 1.232879877090454 seconds
# done with pair (idx, jdx) (97, 5) in 1.6198270320892334 seconds
# done with pair (idx, jdx) (97, 6) in 1.807631015777588 seconds
# done with pair (idx, jdx) (97, 7) in 2.307307004928589 seconds
# done with pair (idx, jdx) (98, 0) in 0.08379793167114258 seconds
# done with pair (idx, jdx) (98, 1) in 0.29404592514038086 seconds
# done with pair (idx, jdx) (98, 2) in 0.3887181282043457 seconds
# done with pair (idx, jdx) (98, 3) in 0.5971648693084717 seconds
# done with pair (idx, jdx) (98, 4) in 1.003533124923706 seconds
# done with pair (idx, jdx) (98, 5) in 1.4679040908813477 seconds
# done with pair (idx, jdx) (98, 6) in 1.8334910869598389 seconds
# done with pair (idx, jdx) (98, 7) in 2.2418251037597656 seconds
# done with pair (idx, jdx) (99, 0) in 0.14677929878234863 seconds
# done with pair (idx, jdx) (99, 1) in 0.19597196578979492 seconds
# done with pair (idx, jdx) (99, 2) in 0.39110708236694336 seconds
# done with pair (idx, jdx) (99, 3) in 0.5612499713897705 seconds
# done with pair (idx, jdx) (99, 4) in 1.1113088130950928 seconds
# done with pair (idx, jdx) (99, 5) in 1.447364091873169 seconds
# done with pair (idx, jdx) (99, 6) in 1.863217830657959 seconds
# done with pair (idx, jdx) (99, 7) in 2.2734289169311523 seconds
# loop took 834.5345830917358 seconds
